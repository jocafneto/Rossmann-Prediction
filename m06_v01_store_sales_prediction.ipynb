# %% [markdown]
# # 0.0. IMPORTS

# %%
import math
import json
import requests
import numpy      as np
import pandas     as pd
import seaborn    as sns
import pickle
import random
import warnings
import inflection


from datetime import timedelta
from scipy                 import stats    as ss
from boruta                import BorutaPy
from tabulate              import tabulate
from matplotlib            import pyplot   as plt
from IPython.display       import Image
from sklearn.metrics       import mean_absolute_error, mean_squared_error
from sklearn.ensemble      import RandomForestRegressor
from pycorrcat.pycorrcat   import plot_corr, corr_matrix
from sklearn.linear_model  import LinearRegression, Lasso
from IPython.core.display  import HTML
from sklearn.preprocessing import RobustScaler, MinMaxScaler, LabelEncoder

# %% [markdown]
# ## 0.1. Helper Functions

# %%
def cramer_v( x, y ):
    cm = pd.crosstab( x, y ).values
    
    n = cm.sum()
    r, k = cm.shape
    chi2 = ss.chi2_contingency( cm )[0]
    
    chi2corr = max( 0, chi2 - (k-1)*(r-1)/(n-1) )
    kcorr = k - (k-1)**2/(n-1)
    rcorr = r - (r-1)**2/(n-1)
    
    b = ( chi2corr/n ) / ( min( kcorr-1, rcorr-1) )
    
    v = np.sqrt( b )
    return v

def mean_percentage_error( y, yhat ):
    return np.mean( ( y - yhat ) / y )


def mean_absolute_percentage_error( y, yhat ):
    return np.mean( np.abs( ( y - yhat ) / y ) )
    
def ml_error( model_name, y, yhat ):
    mae = mean_absolute_error( y, yhat )
    mape = mean_absolute_percentage_error( y, yhat )
    rmse = np.sqrt( mean_squared_error( y, yhat ) )
    
    return pd.DataFrame( {'Model Name': model_name,
                          'MAE': mae,
                          'MAPE': mape,
                          'RMSE': rmse }, index=[0] )

def cross_validation( x_training, kfold, model_name, model, verbose=False ):
    mae_list = []
    mape_list = []
    rmse_list = []
    for k in reversed( range( 1, kfold+1 ) ):
        if verbose:
            print('\nKfold Number:{}'.format( k ) )
        
        # start and end validation
        validation_start_date = x_training['date'].max() - datetime.timedelta( days=k*6*7 )
        validation_end_date = x_training['date'].max() - datetime.timedelta( days=(k-1)*6*7 )

        # filtering dataset
        training = x_training[x_training['date'] < validation_start_date]
        validation = x_training[(x_training['date'] >= validation_start_date) & (x_training['date'] <= validation_end_date)]

        # training and validation dataset
        xtraining = training.drop( ['sales', 'date'], axis=1 ) 
        ytraining = training['sales']

        xvalidation = validation.drop( ['sales', 'date'], axis=1 )
        yvalidation = validation['sales']

        # model
        m = model.fit( xtraining, ytraining )

        # prediction
        yhat = m.predict( xvalidation )

        # performance
        m_result = ml_error( model_name, np.expm1( yvalidation ), np.expm1( yhat ) )

        # store performance of each kfold iteration
        mae_list.append(m_result['MAE'])
        mape_list.append(m_result['MAPE'])
        rmse_list.append(m_result['RMSE'])

    return pd.DataFrame( {'Model Name': model_name,
                          'MAE CV': np.round( np.mean( mae_list ), 2 ).astype( str ) + ' +/- ' + np.round( np.std( mae_list ), 2 ).astype( str ),
                          'MAPE CV': np.round( np.mean( mape_list ), 2 ).astype( str ) + ' +/- ' + np.round( np.std( mape_list ), 2 ).astype( str ),
                          'RMSE CV': np.round( np.mean( rmse_list ), 2 ).astype( str ) + ' +/- ' + np.round( np.std( rmse_list ), 2 ).astype( str ) }, index=[0] )

def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# /home/jocafneto/repositorio/DsEmProducao/lib/python3.9/site-packages/IPython/core/magics/pylab.py:162: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.2. Loading data

# %%
df_sales_raw = pd.read_csv( '/home/jocafneto/repositorio/rossmann/data/train.csv', low_memory=False )
df_store_raw = pd.read_csv( '/home/jocafneto/repositorio/rossmann/data/store.csv', low_memory=False )

# merge
df_raw = pd.merge( df_sales_raw, df_store_raw, how='left', on='Store' )

# %% [markdown]
# # 1.0. PASSO 01 - DESCRICAO DOS DADOS

# %%
df1 = df_raw.copy()

# %%
df_raw.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 0      1          5  2015-07-31   5263        555     1      1            0              1         c          a               1270.0                        9.0                    2008.0       0              NaN              NaN              NaN
# 1      2          5  2015-07-31   6064        625     1      1            0              1         a          a                570.0                       11.0                    2007.0       1             13.0           2010.0  Jan,Apr,Jul,Oct
# 2      3          5  2015-07-31   8314        821     1      1            0              1         a          a              14130.0                       12.0                    2006.0       1             14.0           2011.0  Jan,Apr,Jul,Oct
# 3      4          5  2015-07-31  13995       1498     1      1            0              1         c          c                620.0                        9.0                    2009.0       0              NaN              NaN              NaN
# 4      5          5  2015-07-31   4822        559     1      1            0              1         a          a              29910.0                        4.0                    2015.0       0              NaN              NaN              NaN

# %% [markdown]
# ## 1.1. Rename Columns

# %%
cols_old = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday', 
            'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth',
            'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval']

snakecase = lambda x: inflection.underscore( x )

cols_new = list( map( snakecase, cols_old ) )

# rename
df1.columns = cols_new

# %% [markdown]
# ## 1.2. Data Dimensions

# %%
print( 'Number of Rows: {}'.format( df1.shape[0] ) )
print( 'Number of Cols: {}'.format( df1.shape[1] ) )
# Out:
# Number of Rows: 1017209
# Number of Cols: 18

# %% [markdown]
# ## 1.3. Data Types

# %%
df1['date'] = pd.to_datetime( df1['date'] )
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ## 1.4. Check NA

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ## 1.5. Fillout NA

# %%
#competition_distance        
df1['competition_distance'] = df1['competition_distance'].apply( lambda x: 200000.0 if math.isnan( x ) else x )

#competition_open_since_month
df1['competition_open_since_month'] = df1.apply( lambda x: x['date'].month if math.isnan( x['competition_open_since_month'] ) else x['competition_open_since_month'], axis=1 )

#competition_open_since_year 
df1['competition_open_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['competition_open_since_year'] ) else x['competition_open_since_year'], axis=1 )

#promo2_since_week           
df1['promo2_since_week'] = df1.apply( lambda x: x['date'].week if math.isnan( x['promo2_since_week'] ) else x['promo2_since_week'], axis=1 )

#promo2_since_year           
df1['promo2_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['promo2_since_year'] ) else x['promo2_since_year'], axis=1 )

#promo_interval              
month_map = {1: 'Jan',  2: 'Feb',  3: 'Mar',  4: 'Apr',  5: 'May',  6: 'Jun',  7: 'Jul',  8: 'Aug',  9: 'Sep',  10: 'Oct', 11: 'Nov', 12: 'Dec'}

df1['promo_interval'].fillna(0, inplace=True )

df1['month_map'] = df1['date'].dt.month.map( month_map )

df1['is_promo'] = df1[['promo_interval', 'month_map']].apply( lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval'].split( ',' ) else 0, axis=1 )

# %%
df1.isna().sum()
# Out:
# store                           0
# day_of_week                     0
# date                            0
# sales                           0
# customers                       0
# open                            0
# promo                           0
# state_holiday                   0
# school_holiday                  0
# store_type                      0
# assortment                      0
# competition_distance            0
# competition_open_since_month    0
# competition_open_since_year     0
# promo2                          0
# promo2_since_week               0
# promo2_since_year               0
# promo_interval                  0
# month_map                       0
# is_promo                        0
# dtype: int64

# %% [markdown]
# ## 1.6. Change Data Types

# %%
# competiton
df1['competition_open_since_month'] = df1['competition_open_since_month'].astype( int )
df1['competition_open_since_year'] = df1['competition_open_since_year'].astype( int )
    
# promo2
df1['promo2_since_week'] = df1['promo2_since_week'].astype( int )
df1['promo2_since_year'] = df1['promo2_since_year'].astype( int )

# %% [markdown]
# ## 1.7. Descriptive Statistics

# %%
num_attributes = df1.select_dtypes( include=['int64', 'float64'] )
cat_attributes = df1.select_dtypes( exclude=['int64', 'float64', 'datetime64[ns]'] )

# %% [markdown]
# ### 1.7.1. Numerical Atributes

# %%
# Central Tendency - mean, meadina 
ct1 = pd.DataFrame( num_attributes.apply( np.mean ) ).T
ct2 = pd.DataFrame( num_attributes.apply( np.median ) ).T

# dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame( num_attributes.apply( np.std ) ).T 
d2 = pd.DataFrame( num_attributes.apply( min ) ).T 
d3 = pd.DataFrame( num_attributes.apply( max ) ).T 
d4 = pd.DataFrame( num_attributes.apply( lambda x: x.max() - x.min() ) ).T 
d5 = pd.DataFrame( num_attributes.apply( lambda x: x.skew() ) ).T 
d6 = pd.DataFrame( num_attributes.apply( lambda x: x.kurtosis() ) ).T 

# concatenar
m = pd.concat( [d2, d3, d4, ct1, ct2, d1, d5, d6] ).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
m
# Out:
#                       attributes     min       max     range         mean  median           std       skew    kurtosis
# 0                          store     1.0    1115.0    1114.0   558.429727   558.0    321.908493  -0.000955   -1.200524
# 1                    day_of_week     1.0       7.0       6.0     3.998341     4.0      1.997390   0.001593   -1.246873
# 2                          sales     0.0   41551.0   41551.0  5773.818972  5744.0   3849.924283   0.641460    1.778375
# 3                      customers     0.0    7388.0    7388.0   633.145946   609.0    464.411506   1.598650    7.091773
# 4                           open     0.0       1.0       1.0     0.830107     1.0      0.375539  -1.758045    1.090723
# 5                          promo     0.0       1.0       1.0     0.381515     0.0      0.485758   0.487838   -1.762018
# 6                 school_holiday     0.0       1.0       1.0     0.178647     0.0      0.383056   1.677842    0.815154
# 7           competition_distance    20.0  200000.0  199980.0  5935.442677  2330.0  12547.646829  10.242344  147.789712
# 8   competition_open_since_month     1.0      12.0      11.0     6.786849     7.0      3.311085  -0.042076   -1.232607
# 9    competition_open_since_year  1900.0    2015.0     115.0  2010.324840  2012.0      5.515591  -7.235657  124.071304
# 10                        promo2     0.0       1.0       1.0     0.500564     1.0      0.500000  -0.002255   -1.999999
# 11             promo2_since_week     1.0      52.0      51.0    23.619033    22.0     14.310057   0.178723   -1.184046
# 12             promo2_since_year  2009.0    2015.0       6.0  2012.793297  2013.0      1.662657  -0.784436   -0.210075
# 13                      is_promo     0.0       1.0       1.0     0.165966     0.0      0.372050   1.795644    1.224338

# %%
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month             int64
# competition_open_since_year              int64
# promo2                                   int64
# promo2_since_week                        int64
# promo2_since_year                        int64
# promo_interval                          object
# month_map                               object
# is_promo                                 int64
# dtype: object

# %%
sns.distplot( df1['competition_distance'], kde=False )
# Out:
# /home/jocafneto/repositorio/DsEmProducao/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='competition_distance'>

# %% [markdown]
# ### 1.7.2. Categorical Atributes

# %%
cat_attributes.apply( lambda x: x.unique().shape[0] )
# Out:
# state_holiday      4
# store_type         4
# assortment         3
# promo_interval     4
# month_map         12
# dtype: int64

# %%
aux = df1[(df1['state_holiday'] != '0') & (df1['sales'] > 0)]

plt.subplot( 1, 3, 1 )
sns.boxplot( x='state_holiday', y='sales', data=aux )

plt.subplot( 1, 3, 2 )
sns.boxplot( x='store_type', y='sales', data=aux )

plt.subplot( 1, 3, 3 )
sns.boxplot( x='assortment', y='sales', data=aux )
# Out:
# <AxesSubplot:xlabel='assortment', ylabel='sales'>

# %% [markdown]
# # 2.0. PASSO 02 - FEATURE ENGINEERING

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1. Mapa Mental de Hipoteses

# %%
Image('img/MindMapHypotesis.png')

# %% [markdown]
# ## 2.2. Criacao das Hipoteses

# %% [markdown]
# ### 2.2.1. Hipoteses Loja

# %% [markdown]
# **1.** Lojas com número maior de funcionários deveriam vender mais.
#
# **2.** Lojas com maior capacidade de estoque deveriam vender mais.
#
# **3.** Lojas com maior porte deveriam vender mais.
#
# **4.** Lojas com maior sortimentos deveriam vender mais.
#
# **5.** Lojas com competidores mais próximos deveriam vender menos.
#
# **6.** Lojas com competidores à mais tempo deveriam vendem mais.

# %% [markdown]
# ### 2.2.2. Hipoteses Produto

# %% [markdown]
# **1.** Lojas que investem mais em Marketing deveriam vender mais.
#
# **2.** Lojas com maior exposição de produto deveriam vender mais.
#
# **3.** Lojas com produtos com preço menor deveriam vender mais.
#
# **5.** Lojas com promoções mais agressivas ( descontos maiores ), deveriam vender mais.
#
# **6.** Lojas com promoções ativas por mais tempo deveriam vender mais.
#
# **7.** Lojas com mais dias de promoção deveriam vender mais.
#
# **8.** Lojas com mais promoções consecutivas deveriam vender mais.

# %% [markdown]
# ### 2.2.3. Hipoteses Tempo

# %% [markdown]
# **1.** Lojas abertas durante o feriado de Natal deveriam vender mais.
#
# **2.** Lojas deveriam vender mais ao longo dos anos.
#
# **3.** Lojas deveriam vender mais no segundo semestre do ano.
#
# **4.** Lojas deveriam vender mais depois do dia 10 de cada mês.
#
# **5.** Lojas deveriam vender menos aos finais de semana.
#
# **6.** Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ## 2.3. Lista Final de Hipóteses

# %% [markdown]
# **1.** Lojas com maior sortimentos deveriam vender mais.
#
# **2.** Lojas com competidores mais próximos deveriam vender menos.
#
# **3.** Lojas com competidores à mais tempo deveriam vendem mais.

# %% [markdown]
# **4.** Lojas com promoções ativas por mais tempo deveriam vender mais.
#
# **5.** Lojas com mais dias de promoção deveriam vender mais.
#
# **7.** Lojas com mais promoções consecutivas deveriam vender mais.

# %% [markdown]
# **8.** Lojas abertas durante o feriado de Natal deveriam vender mais.
#
# **9.** Lojas deveriam vender mais ao longo dos anos.
#
# **10.** Lojas deveriam vender mais no segundo semestre do ano.
#
# **11.** Lojas deveriam vender mais depois do dia 10 de cada mês.
#
# **12.** Lojas deveriam vender menos aos finais de semana.
#
# **13.** Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ## 2.4. Feature Engineering

# %%
# year
df2['year'] = df2['date'].dt.year

# month
df2['month'] = df2['date'].dt.month

# day
df2['day'] = df2['date'].dt.day

# week of year
df2['week_of_year'] = df2['date'].dt.weekofyear

# year week
df2['year_week'] = df2['date'].dt.strftime( '%Y-%W' )

# competition since
df2['competition_since'] = df2.apply( lambda x: datetime.datetime( year=x['competition_open_since_year'], month=x['competition_open_since_month'],day=1 ), axis=1 )
df2['competition_time_month'] = ( ( df2['date'] - df2['competition_since'] )/30 ).apply( lambda x: x.days ).astype( int )

# promo since
df2['promo_since'] = df2['promo2_since_year'].astype( str ) + '-' + df2['promo2_since_week'].astype( str )
df2['promo_since'] = df2['promo_since'].apply( lambda x: datetime.datetime.strptime( x + '-1', '%Y-%W-%w' ) - datetime.timedelta( days=7 ) )
df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since'] )/7 ).apply( lambda x: x.days ).astype( int )

# assortment
df2['assortment'] = df2['assortment'].apply( lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended' )

# state holiday
df2['state_holiday'] = df2['state_holiday'].apply( lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' else 'christmas' if x == 'c' else 'regular_day' )
# Out:
# /tmp/ipykernel_22053/3893170355.py:11: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df2['week_of_year'] = df2['date'].dt.weekofyear

# %%
df2.head().T
# Out:
#                                                 0                    1                    2                    3                    4
# store                                           1                    2                    3                    4                    5
# day_of_week                                     5                    5                    5                    5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00  2015-07-31 00:00:00  2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                        5263                 6064                 8314                13995                 4822
# customers                                     555                  625                  821                 1498                  559
# open                                            1                    1                    1                    1                    1
# promo                                           1                    1                    1                    1                    1
# state_holiday                         regular_day          regular_day          regular_day          regular_day          regular_day
# school_holiday                                  1                    1                    1                    1                    1
# store_type                                      c                    a                    a                    c                    a
# assortment                                  basic                basic                basic             extended                basic
# competition_distance                       1270.0                570.0              14130.0                620.0              29910.0
# competition_open_since_month                    9                   11                   12                    9                    4
# competition_open_since_year                  2008                 2007                 2006                 2009                 2015
# promo2                                          0                    1                    1                    0                    0
# promo2_since_week                              31                   13                   14                   31                   31
# promo2_since_year                            2015                 2010                 2011                 2015                 2015
# promo_interval                                  0      Jan,Apr,Jul,Oct      Jan,Apr,Jul,Oct                    0                    0
# month_map                                     Jul                  Jul                  Jul                  Jul                  Jul
# is_promo                                        0                    1                    1                    0                    0
# year                                         2015                 2015                 2015                 2015                 2015
# month                                           7                    7                    7                    7                    7
# day                                            31                   31                   31                   31                   31
# week_of_year                                   31                   31                   31                   31                   31
# year_week                                 2015-30              2015-30              2015-30              2015-30              2015-30
# competition_since             2008-09-01 00:00:00  2007-11-01 00:00:00  2006-12-01 00:00:00  2009-09-01 00:00:00  2015-04-01 00:00:00
# competition_time_month                         84                   94                  105                   71                    4
# promo_since                   2015-07-27 00:00:00  2010-03-22 00:00:00  2011-03-28 00:00:00  2015-07-27 00:00:00  2015-07-27 00:00:00
# promo_time_week                                 0                  279                  226                    0                    0

# %% [markdown]
# # 3.0. PASSO 03 - FILTRAGEM DE VARIÁVEIS

# %%
df3 = df2.copy()

# %% [markdown]
# ## 3.1. Filtragem das Linhas

# %%
df3 = df3[(df3['open'] != 0) & (df3['sales'] > 0)]

# %% [markdown]
# ## 3.2. Selecao das Colunas

# %%
cols_drop = ['customers', 'open', 'promo_interval', 'month_map']
df3 = df3.drop( cols_drop, axis=1 )

# %% [markdown]
# # 4.0. PASSO 04 - ANALISE EXPLORATÓRIA DE DADOS

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1. Analise Univariada

# %% [markdown]
# ### 4.1.1. Response Variable

# %%
sns.distplot(df4['sales'])
# Out:
# /home/jocafneto/repositorio/DsEmProducao/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# ### 4.1.2. Numerical Variable

# %%
num_attributes.hist(bins=25);

# %% [markdown]
# ### 4.1.3. Categorical Variable

# %%
df4['assortment'].drop_duplicates()
# Out:
# 0         basic
# 3      extended
# 258       extra
# Name: assortment, dtype: object

# %%
# state holiday
plt.subplot(3,2,1)
a = df4[df4['state_holiday'] != 'regular_day']
sns.countplot(a['state_holiday'])

plt.subplot(3,2,2)
sns.kdeplot(df4[df4['state_holiday'] == 'public_holiday']['sales'], label ='public_holiday', shade=True)
sns.kdeplot(df4[df4['state_holiday'] == 'easter_holiday']['sales'], label ='easter_holiday', shade=True)
sns.kdeplot(df4[df4['state_holiday'] == 'christmas']['sales'], label ='christmas', shade=True)


# store_type
plt.subplot(3,2,3)
sns.countplot(df4['store_type'])

plt.subplot(3,2,4)
sns.kdeplot(df4[df4['store_type'] == 'a']['sales'], label ='a', shade=True)
sns.kdeplot(df4[df4['store_type'] == 'b']['sales'], label ='b', shade=True)
sns.kdeplot(df4[df4['store_type'] == 'c']['sales'], label ='c', shade=True)
sns.kdeplot(df4[df4['store_type'] == 'd']['sales'], label ='d', shade=True)


# assortment
plt.subplot(3,2,5)
sns.countplot(df4['assortment'])

plt.subplot(3,2,6)
sns.kdeplot(df4[df4['assortment'] == 'basic']['sales'], label ='basic', shade=True)
sns.kdeplot(df4[df4['assortment'] == 'extended']['sales'], label ='extended', shade=True)
sns.kdeplot(df4[df4['assortment'] == 'extra']['sales'], label ='extra', shade=True)
# Out:
# /home/jocafneto/repositorio/DsEmProducao/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/jocafneto/repositorio/DsEmProducao/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/jocafneto/repositorio/DsEmProducao/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# ## 4.2. Analise Bivariada

# %% [markdown]
# ### 1. Lojas com maior sortimentos deveriam vender mais.
#
# **FALSA**

# %%
aux1 = df4[['assortment', 'sales']].groupby('assortment').sum().reset_index()
sns.barplot(x='assortment', y='sales', data=aux1);

aux2 = df4[['year_week', 'assortment', 'sales']].groupby(['year_week', 'assortment']).sum().reset_index()
aux2.pivot(index='year_week', columns='assortment', values='sales').plot()

aux3 = aux2[aux2['assortment'] == 'extra']
aux3.pivot(index='year_week', columns='assortment', values='sales').plot()
# Out:
# <AxesSubplot:xlabel='year_week'>

# %% [markdown]
# ### 2. Lojas com competidores mais próximos deveriam vender menos.
# **FALSA**

# %%
aux1 = df4[['competition_distance', 'sales']].groupby('competition_distance').sum().reset_index()

plt.subplot(1, 3, 1)
sns.scatterplot(x='competition_distance', y='sales', data=aux1);

plt.subplot(1, 3, 2)
bins = list( np.arange(0, 20000, 1000) )
aux1['competition_distance_binned'] = pd.cut( aux1['competition_distance'], bins=bins )
aux2 = aux1[['competition_distance_binned', 'sales']].groupby('competition_distance_binned' ).sum().reset_index()
sns.barplot( x='competition_distance_binned', y='sales', data=aux2 );
plt.xticks(rotation=80)

plt.subplot(1, 3, 3)
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### 3. Lojas com competidores à mais tempo deveriam vendem mais.
# **FALSA**

# %%
plt.subplot( 1, 3, 1 )
aux1 = df4[['competition_time_month', 'sales']].groupby('competition_time_month').sum().reset_index()
aux2 = aux1[( aux1['competition_time_month'] < 120 ) & ( aux1['competition_time_month'] != 0 )]

sns.barplot( x='competition_time_month', y='sales', data=aux2 );
plt.xticks( rotation=90 );

plt.subplot( 1, 3, 2 )
sns.regplot( x='competition_time_month', y='sales', data=aux2 );

plt.subplot( 1, 3, 3 )
sns.heatmap( aux1.corr( method='pearson'), annot=True );

# %% [markdown]
# ### **4.** Lojas com promoções ativas por mais tempo deveriam vender mais.
# **FALSA**

# %%
aux1 = df4[['promo_time_week','sales']].groupby( 'promo_time_week' ).sum().reset_index()

grid = GridSpec( 2, 3 )

plt.subplot(grid[0,0])
aux2 = aux1[aux1['promo_time_week'] > 0] # promo extendido
sns.barplot( x='promo_time_week', y='sales', data=aux2 );
plt.xticks( rotation=90 );

plt.subplot(grid[0,1])
sns.regplot( x='promo_time_week', y='sales', data=aux2 );

plt.subplot(grid[1,0])
aux3 = aux1[aux1['promo_time_week'] < 0] # promo regular
sns.barplot( x='promo_time_week', y='sales', data=aux3 );
plt.xticks( rotation=90 );

plt.subplot(grid[1,1])
sns.regplot( x='promo_time_week', y='sales', data=aux3 );

plt.subplot(grid[:,2])
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### <s>**5.** Lojas com mais dias de promoção deveriam vender mais.</s>

# %% [markdown]
# ### **7.** Lojas com mais promoções consecutivas deveriam vender mais.
# **FALSA**

# %%
df4[['promo', 'promo2', 'sales']].groupby( ['promo', 'promo2'] ).sum().reset_index()
# Out:
#    promo  promo2       sales
# 0      0       0  1482612096
# 1      0       1  1289362241
# 2      1       0  1628930532
# 3      1       1  1472275754

# %%
aux1 = df4[( df4['promo'] == 1 ) & (df4['promo2'] == 1 )][['year_week', 'sales']].groupby( 'year_week' ).sum().reset_index()
ax = aux1.plot()

aux2 = df4[( df4['promo'] == 1 ) & (df4['promo2'] == 0 )][['year_week', 'sales']].groupby( 'year_week' ).sum().reset_index()
aux2.plot( ax=ax )

ax.legend( labels=['Tradicional + Extendida', 'Tradicional'] );

# %% [markdown]
# ### **8.** Lojas abertas durante o feriado de Natal deveriam vender mais.
# **FALSA**

# %%
plt.subplot( 1, 2, 1 );
aux = df4[df4['state_holiday'] != 'regular_day']
aux1 = aux[['state_holiday', 'sales']].groupby( 'state_holiday' ).sum().reset_index()
sns.barplot( x='state_holiday', y='sales', data=aux1 );

plt.subplot( 1, 2, 2 );
aux2 = aux[['year', 'state_holiday', 'sales']].groupby( ['year', 'state_holiday'] ).sum().reset_index()
sns.barplot( x='year', y='sales', hue='state_holiday', data=aux2 );

# %% [markdown]
# ### **9.** Lojas deveriam vender mais ao longo dos anos.
# **FALSA**

# %%
plt.subplot( 1, 3, 1 );
aux1 = df4[['year', 'sales']].groupby( 'year' ).sum().reset_index()
sns.barplot( x='year', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 );
sns.regplot( x='year', y='sales', data=aux1 );

plt.subplot( 1, 3, 3 );
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### **10.** Lojas deveriam vender mais no segundo semestre do ano.
# **FALSA**

# %%
plt.subplot( 1, 3, 1 );
aux1 = df4[['month', 'sales']].groupby( 'month' ).sum().reset_index()
sns.barplot( x='month', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 );
sns.regplot( x='month', y='sales', data=aux1 );

plt.subplot( 1, 3, 3 );
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### **11.** Lojas deveriam vender mais depois do dia 10 de cada mês.
# **VERDADEIRA**

# %%
plt.subplot( 2, 2, 1 );
aux1 = df4[['day', 'sales']].groupby( 'day' ).sum().reset_index()
sns.barplot( x='day', y='sales', data=aux1 );

plt.subplot( 2, 2, 2 );
sns.regplot( x='day', y='sales', data=aux1 );

plt.subplot( 2, 2, 3 );
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

aux1['before_after'] = aux1['day'].apply( lambda x: 'before_10_days' if x<= 10 else 'after_10_days' )
aux2 = aux1[['before_after', 'sales']].groupby( 'before_after' ).sum().reset_index()

plt.subplot( 2, 2, 4 );
sns.barplot( x='before_after', y='sales', data=aux2 );

# %% [markdown]
# ### **12.** Lojas deveriam vender menos aos finais de semana.
# **VERDADEIRA**

# %%
plt.subplot( 1, 3, 1 );
aux1 = df4[['day_of_week', 'sales']].groupby( 'day_of_week' ).sum().reset_index()
sns.barplot( x='day_of_week', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 );
sns.regplot( x='day_of_week', y='sales', data=aux1 );

plt.subplot( 1, 3, 3 );
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# ### **13.** Lojas deveriam vender menos durante os feriados escolares.
# **VERDADEIRA** Vendem menos exceto nos meses de julho e agosto

# %%
plt.subplot( 2, 1, 1 );
aux1 = df4[['school_holiday', 'sales']].groupby( 'school_holiday' ).sum().reset_index()
sns.barplot( x='school_holiday', y='sales', data=aux1 );

plt.subplot( 2, 1, 2 );
aux2 = df4[['month', 'school_holiday', 'sales']].groupby( ['month', 'school_holiday'] ).sum().reset_index()
sns.barplot( x='month', y='sales', hue='school_holiday', data=aux2 );

# %% [markdown]
# ## Resumo das Hipóteses

# %%
tab = [['Hipoteses', 'Conclusao', 'Relevância'],
      ['H1', 'falsa', 'baixa'],
      ['H2', 'falsa', 'media'],
      ['H3', 'falsa', 'media'],
      ['H4', 'falsa', 'baixa'],
      ['H5', '-', '-'],
      ['H7', 'falsa', 'baixa'],
      ['H8', 'falsa', 'media'],
      ['H9', 'falsa', 'alta'],
      ['H10', 'falsa', 'alta'],
      ['H11', 'verdadeira', 'alta'],
      ['H12', 'verdadeira', 'alta'],
      ['H13', 'verdadeira', 'baixa']]

print( tabulate( tab, headers='firstrow'))
# Out:
# Hipoteses    Conclusao    Relevância
# -----------  -----------  ------------
# H1           falsa        baixa
# H2           falsa        media
# H3           falsa        media
# H4           falsa        baixa
# H5           -            -
# H7           falsa        baixa
# H8           falsa        media
# H9           falsa        alta
# H10          falsa        alta
# H11          verdadeira   alta
# H12          verdadeira   alta
# H13          verdadeira   baixa

# %% [markdown]
# ## 4.3. Analise Multivariada

# %% [markdown]
# ### 4.3.1 Numerical Attributes

# %%
correlation = num_attributes.corr( method='pearson')
sns.heatmap( correlation, annot=True);

# %% [markdown]
# ### 4.3.2 Categorical Attributes

# %%
a = df4.select_dtypes( include='object' )

# %%
a1 = cramer_v(a['state_holiday'], a['state_holiday'])
a2 = cramer_v(a['state_holiday'], a['store_type'])
a3 = cramer_v(a['state_holiday'], a['assortment'])

a4 = cramer_v(a['store_type'], a['state_holiday'])
a5 = cramer_v(a['store_type'], a['store_type'])
a6 = cramer_v(a['store_type'], a['assortment'])

a7 = cramer_v(a['assortment'], a['state_holiday'])
a8 = cramer_v(a['assortment'], a['store_type'])
a9 = cramer_v(a['assortment'], a['assortment'])

d = pd.DataFrame( {'state_holiday': [a1, a2, a3],
                   'store_type': [a4, a5, a6],
                   'assortment': [a7, a8, a9] })
d.set_index( d.columns )

sns.heatmap( d, annot=True);

# %%
correlation_matrix = corr_matrix(df4, ['state_holiday', 'store_type', 'assortment'])

# %%
plot_corr(df4, ['state_holiday', 'store_type', 'assortment'] );

# %% [markdown]
# # 5.0. PASSO 05 - DATA PREPARATION

# %%
df5 = df4.copy()

# %% [markdown]
# ## 5.1 Normalização

# %% [markdown]
# ## 5.2 Rescaling

# %%
rs = RobustScaler()
mms = MinMaxScaler()
# competition distance
df5['competition_distance'] = rs.fit_transform( df5[['competition_distance']].values )
pickle.dump( rs, open( 'parameter/competition_distance_scaler.pkl', 'wb' ) )

# competition time month
df5['competition_time_month'] = rs.fit_transform( df5[['competition_time_month']].values )
pickle.dump( rs, open( 'parameter/competition_time_month_scaler.pkl', 'wb' ) )

# promo time week
df5['promo_time_week'] = mms.fit_transform( df5[['promo_time_week']].values )
pickle.dump( mms, open( 'parameter/promo_time_week_scaler.pkl', 'wb' ) )

# year
df5['year'] = mms.fit_transform( df5[['year']].values )
pickle.dump( mms, open( 'parameter/year_scaler.pkl', 'wb' ) )

# %% [markdown]
# ## 5.3 Transformação

# %% [markdown]
# ### 5.3.1 Encoding

# %%
# state holiday - One Hot Encoding
df5 = pd.get_dummies(df5, prefix=['state_holiday'], columns=['state_holiday'])

# store type - Label Encoding
le = LabelEncoder()
df5['store_type'] = le.fit_transform( df5['store_type'] )
pickle.dump( le, open( 'parameter/store_type_scaler.pkl', 'wb' ) )

# assortment - Ordinal Encoding
assortment_dict = {'basic':1, 'extra':2, 'extended':3}
df5['assortment'] = df5['assortment'].map( assortment_dict )

# %% [markdown]
# ### 5.3.2 Respose Variable Transformation

# %%
df5['sales'] = np.log1p( df5['sales'] )

# %%
sns.distplot( df5['sales'] )
# Out:
# /home/jocafneto/repositorio/DsEmProducao/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# ### 5.3.3 Nature Transformation

# %%
# day of week
df5['day_of_week_sin'] = df5['day_of_week'].apply( lambda x: np.sin( x * ( 2. * np.pi/7) ) )
df5['day_of_week_cos'] = df5['day_of_week'].apply( lambda x: np.cos( x * ( 2. * np.pi/7) ) )

# month
df5['month_sin'] = df5['month'].apply( lambda x: np.sin( x * ( 2. * np.pi/12) ) )
df5['month_cos'] = df5['month'].apply( lambda x: np.cos( x * ( 2. * np.pi/12) ) )

# day
df5['day_sin'] = df5['day'].apply( lambda x: np.sin( x * ( 2. * np.pi/30) ) )
df5['day_cos'] = df5['day'].apply( lambda x: np.cos( x * ( 2. * np.pi/30) ) )

# week of year
df5['week_of_year_sin'] = df5['week_of_year'].apply( lambda x: np.sin( x * ( 2. * np.pi/52) ) )
df5['week_of_year_cos'] = df5['week_of_year'].apply( lambda x: np.cos( x * ( 2. * np.pi/52) ) )

# %%
df5.head()
# Out:
#    store  day_of_week       date     sales  promo  school_holiday  store_type  assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year  is_promo  year  month  day  week_of_year year_week competition_since  competition_time_month promo_since  promo_time_week  state_holiday_christmas  state_holiday_easter_holiday  state_holiday_public_holiday  state_holiday_regular_day  day_of_week_sin  day_of_week_cos  month_sin  month_cos   day_sin   day_cos  week_of_year_sin  week_of_year_cos
# 0      1            5 2015-07-31  8.568646      1               1           2           1             -0.170968                             9                         2008       0                 31               2015         0   1.0      7   31            31   2015-30        2008-09-01                0.918919  2015-07-27         0.287016                        0                             0                             0                          1        -0.974928        -0.222521       -0.5  -0.866025  0.207912  0.978148         -0.568065         -0.822984
# 1      2            5 2015-07-31  8.710290      1               1           0           1             -0.283871                            11                         2007       1                 13               2010         1   1.0      7   31            31   2015-30        2007-11-01                1.054054  2010-03-22         0.922551                        0                             0                             0                          1        -0.974928        -0.222521       -0.5  -0.866025  0.207912  0.978148         -0.568065         -0.822984
# 2      3            5 2015-07-31  9.025816      1               1           0           1              1.903226                            12                         2006       1                 14               2011         1   1.0      7   31            31   2015-30        2006-12-01                1.202703  2011-03-28         0.801822                        0                             0                             0                          1        -0.974928        -0.222521       -0.5  -0.866025  0.207912  0.978148         -0.568065         -0.822984
# 3      4            5 2015-07-31  9.546527      1               1           2           3             -0.275806                             9                         2009       0                 31               2015         0   1.0      7   31            31   2015-30        2009-09-01                0.743243  2015-07-27         0.287016                        0                             0                             0                          1        -0.974928        -0.222521       -0.5  -0.866025  0.207912  0.978148         -0.568065         -0.822984
# 4      5            5 2015-07-31  8.481151      1               1           0           1              4.448387                             4                         2015       0                 31               2015         0   1.0      7   31            31   2015-30        2015-04-01               -0.162162  2015-07-27         0.287016                        0                             0                             0                          1        -0.974928        -0.222521       -0.5  -0.866025  0.207912  0.978148         -0.568065         -0.822984

# %% [markdown]
# # 6.0. PASSO 06 - FEATURE SELECTION

# %%
df6 = df5.copy()
# df6 = pd.read_csv( '/home/jocafneto/repositorio/rossmann/df6_complete.csv', low_memory=False )

# %%
# df6 = df6.drop( 'Unnamed: 0', axis=1)

# %%
df6.head()
# Out:
#    store  day_of_week       date     sales  promo  school_holiday  store_type  assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year  is_promo  year  month  day  week_of_year year_week competition_since  competition_time_month promo_since  promo_time_week  state_holiday_christmas  state_holiday_easter_holiday  state_holiday_public_holiday  state_holiday_regular_day  day_of_week_sin  day_of_week_cos  month_sin  month_cos   day_sin   day_cos  week_of_year_sin  week_of_year_cos
# 0      1            5 2015-07-31  8.568646      1               1           2           1             -0.170968                             9                         2008       0                 31               2015         0   1.0      7   31            31   2015-30        2008-09-01                0.918919  2015-07-27         0.287016                        0                             0                             0                          1        -0.974928        -0.222521       -0.5  -0.866025  0.207912  0.978148         -0.568065         -0.822984
# 1      2            5 2015-07-31  8.710290      1               1           0           1             -0.283871                            11                         2007       1                 13               2010         1   1.0      7   31            31   2015-30        2007-11-01                1.054054  2010-03-22         0.922551                        0                             0                             0                          1        -0.974928        -0.222521       -0.5  -0.866025  0.207912  0.978148         -0.568065         -0.822984
# 2      3            5 2015-07-31  9.025816      1               1           0           1              1.903226                            12                         2006       1                 14               2011         1   1.0      7   31            31   2015-30        2006-12-01                1.202703  2011-03-28         0.801822                        0                             0                             0                          1        -0.974928        -0.222521       -0.5  -0.866025  0.207912  0.978148         -0.568065         -0.822984
# 3      4            5 2015-07-31  9.546527      1               1           2           3             -0.275806                             9                         2009       0                 31               2015         0   1.0      7   31            31   2015-30        2009-09-01                0.743243  2015-07-27         0.287016                        0                             0                             0                          1        -0.974928        -0.222521       -0.5  -0.866025  0.207912  0.978148         -0.568065         -0.822984
# 4      5            5 2015-07-31  8.481151      1               1           0           1              4.448387                             4                         2015       0                 31               2015         0   1.0      7   31            31   2015-30        2015-04-01               -0.162162  2015-07-27         0.287016                        0                             0                             0                          1        -0.974928        -0.222521       -0.5  -0.866025  0.207912  0.978148         -0.568065         -0.822984

# %% [markdown]
# ## 6.1 Splitting dataframe into training and test dataset

# %%
cols_drop = ['week_of_year', 'day_of_week', 'day', 'month', 'promo_since', 'competition_since', 'year_week']
df6 = df6.drop( cols_drop, axis=1 )

# %%
# df6['date'] = pd.to_datetime( df6['date'] )
# df6.dtypes

# %%
# df6[['store', 'date']].groupby( 'store' ).max().reset_index()['date'][0] - datetime.timedelta( days=6*7 )

# %%
# training dataset
X_train = df6[df6['date'] < '2015-06-19']
y_train = X_train['sales']

# test dataset
X_test = df6[df6['date'] >= '2015-06-19']
y_test = X_test['sales']

print( 'Training min date: {}'.format( X_train['date'].min() ) )
print( 'Training max date: {}'.format( X_train['date'].max() ) )

print( 'Testing min date: {}'.format( X_test['date'].min() ) )
print( 'Testing max date: {}'.format( X_test['date'].max() ) )
# Out:
# Training min date: 2013-01-01 00:00:00
# Training max date: 2015-06-18 00:00:00
# Testing min date: 2015-06-19 00:00:00
# Testing max date: 2015-07-31 00:00:00

# %% [markdown]
# ## 6.2 Boruta as feature selector

# %%
# # training and test dataset for Boruta
# x_train_n = x_train.drop( ['date', 'sales'], axis=1 ).values
# y_train_n = y_train.values.ravel()

# # define RandomForestRegressor
# rf = RandomForestRegressor( n_jobs=-1 )

# # define boruta 
# boruta = BorutaPy( rf, n_estimators='auto', verbose=2, random_state=42 ).fit( x_train_n, y_train_n )

# %% [markdown]
# ### 6.2.1 Best Features from Boruta

# %%
# cols_selected = boruta.support_.tolist()

# # best features
# x_train_fs = x_train.drop( ['date', 'sales'], axis=1 )
# cols_selected_boruta = x_train_fs.iloc[:,cols_selected].columns.to_list()

# # not selected boruta
# cols_not_selected_boruta = list( np.setdiff1d( x_train_fs.columns, cols_selected_boruta ) )

# %%
cols_selected_boruta = ['store',
                        'promo',
                        'store_type',
                        'assortment',
                        'competition_distance',
                        'competition_open_since_month',
                        'competition_open_since_year',
                        'promo2',
                        'promo2_since_week',
                        'promo2_since_year',
                        'competition_time_month',
                        'promo_time_week',
                        'day_of_week_sin',
                        'day_of_week_cos',
                        'month_sin',
                        'month_cos',
                        'day_sin',
                        'day_cos',
                        'week_of_year_sin',
                        'week_of_year_cos']

cols_not_selected_boruta = ['is_promo',
                            'school_holiday',
                            'state_holiday_christmas',
                            'state_holiday_easter_holiday',
                            'state_holiday_public_holiday',
                            'state_holiday_regular_day',
                            'year']

# columns to add
feature_to_add = ['date', 'sales']

# final features
cols_selected_boruta_full = cols_selected_boruta.copy()
cols_selected_boruta_full.extend( feature_to_add )

# %% [markdown]
# # 7.0. PASSO 07 - MACHINE LEARNING MODELING

# %%
df7 = df6.copy()

# %%
x_train = X_train[cols_selected_boruta]
x_test = X_test[cols_selected_boruta]

# Time Series Data Preparation
x_training = X_train[cols_selected_boruta_full]

# %% [markdown]
# ## 7.1 Average Model

# %%
aux1 = x_test.copy()
aux1['sales'] = y_test.copy()

# prediction
aux2 = aux1[['store', 'sales']].groupby( 'store' ).mean().reset_index().rename( columns={'sales':'predictions'} )
aux1 = pd.merge( aux1, aux2, how='left', on='store' )
yhat_baseline = aux1['predictions']

# performances
baseline_result = ml_error( 'Average Model', np.expm1( y_test ), np.expm1( yhat_baseline ) )
baseline_result
# Out:
#       Model Name          MAE      MAPE         RMSE
# 0  Average Model  1354.800353  0.455051  1835.135542

# %% [markdown]
# ## 7.2 Linear Regression Model

# %%
# model
lr = LinearRegression().fit( x_train, y_train )

# prediction
yhat_lr = lr.predict( x_test )

# performance
lr_result = ml_error( 'Linear Regression', np.expm1( y_test ), np.expm1( yhat_lr ) )
lr_result
# Out:
#           Model Name          MAE      MAPE         RMSE
# 0  Linear Regression  1867.089774  0.292694  2671.049215

# %% [markdown]
# ### 7.2.1 Linear Regression Model - Cross Validation

# %%
lr_result_cv = cross_validation( x_training, 5, 'Linear Regression', lr, verbose=False )

# %%
lr_result_cv
# Out:
#           Model Name              MAE CV       MAPE CV             RMSE CV
# 0  Linear Regression  2081.73 +/- 295.63  0.3 +/- 0.02  2952.52 +/- 468.37

# %% [markdown]
# ## 7.3 Linear Regression Regularized Model

# %%
# model
lrr = Lasso( alpha=0.01 ).fit( x_train, y_train )

# prediction
yhat_lrr = lrr.predict( x_test )

# performance
lrr_result = ml_error( 'Linear Regression Lasso', np.expm1( y_test ), np.expm1( yhat_lrr ) )
lrr_result
# Out:
#                 Model Name          MAE      MAPE         RMSE
# 0  Linear Regression Lasso  1891.704881  0.289106  2744.451737

# %% [markdown]
# ### 7.3.1 Linear Regression Regularized Model - Cross Validation

# %%
lrr_result_cv = cross_validation( x_training, 5, 'Lasso', lrr, verbose=False )

# %%
lrr_result_cv
# Out:
#   Model Name             MAE CV        MAPE CV             RMSE CV
# 0      Lasso  2116.38 +/- 341.5  0.29 +/- 0.01  3057.75 +/- 504.26

# %% [markdown]
# ## 7.4 Random Forest Regressor (non linear)

# %%
# # model
# rf = RandomForestRegressor( n_estimators=100, n_jobs=-1, random_state=42 ).fit( x_train, y_train )

# # prediction
# yhat_rf = rf.predict( x_test )

# # performance
# rf_result = ml_error( 'Random Forest Regressor', np.expm1( y_test ), np.expm1( yhat_rf ) )
# rf_result

# %% [markdown]
# ### 7.4.1 Random Forest Regressor Model - Cross Validation

# %%
# rf_result_cv = cross_validation( x_training, 5, 'Random Forest', rf, verbose=False )

# %%
# rf_result_cv

# %% [markdown]
# ## 7.5 XGBoost Regressor (non linear)

# %%
from pandas import MultiIndex, Int64Index
import xgboost as xgb
# Out:
# /tmp/ipykernel_3916/4015506071.py:1: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/jocafneto/repositorio/DsEmProducao/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# # model
# model_xgb = xgb.XGBRegressor( objective='reg:squarederror',
#                              n_estimators=100,
#                              eta=0.01,
#                              max_depth=10,
#                              subsample=0.7,
#                              colsample_bytee=0.9 ).fit( x_train, y_train )

# # prediction
# yhat_xgb = model_xgb.predict( x_test )

# # performance
# xgb_result = ml_error( 'XGBoost Regressor', np.expm1( y_test ), np.expm1( yhat_xgb ) )
# xgb_result

# %% [markdown]
# ### 7.5.1 XGBoost Regressor Model - Cross Validation

# %%
# xgb_result_cv = cross_validation( x_training, 5, 'XGBoost Regressor', model_xgb, verbose=False )

# %%
# xgb_result_cv

# %% [markdown]
# ## 7.6 Compare Model's Performance

# %% [markdown]
# ### 7.6.1 Single Performance

# %%
# modelling_result = pd.concat( [baseline_result, lr_result, lrr_result, rf_result, xgb_result] )
modelling_result = pd.concat( [baseline_result, lr_result, lrr_result] )
modelling_result.sort_values( 'RMSE' )
# Out:
#                 Model Name          MAE      MAPE         RMSE
# 0            Average Model  1354.800353  0.455051  1835.135542
# 0        Linear Regression  1867.089774  0.292694  2671.049215
# 0  Linear Regression Lasso  1891.704881  0.289106  2744.451737

# %% [markdown]
# ### 7.6.2 Real Performance - Cross Validation

# %%
# modelling_result = pd.concat( [baseline_result, lr_result_cv, lrr_result_cv, rf_result_cv, xgb_result_cv] )
modelling_result = pd.concat( [lr_result_cv, lrr_result_cv] )
modelling_result.sort_values( 'RMSE CV' )
# Out:
#           Model Name              MAE CV        MAPE CV             RMSE CV
# 0  Linear Regression  2081.73 +/- 295.63   0.3 +/- 0.02  2952.52 +/- 468.37
# 0              Lasso   2116.38 +/- 341.5  0.29 +/- 0.01  3057.75 +/- 504.26

# %% [markdown]
# # 8.0. PASSO 08 - HYPERPARAMETER FINE TUNING

# %% [markdown]
# ## 8.1 Random Search

# %%
warnings.filterwarnings( 'ignore' )

# %%
param = {'n_estimators': [15, 17, 25, 30, 35],
         'eta': [0.01, 0.03],
         'max_depth': [3, 5, 9],
         'subsample': [0.1, 0.5, 0.7],
         'colsample_bytee': [0.3, 0.7, 0.9],
         'min_child_weight': [3, 8, 15]}

MAX_EVAL=2

# %%
# final_result = pd.DataFrame()

# for i in range( MAX_EVAL ):
#     # choose values for parameters randomly
#     hp = { k: random.sample( v, 1 )[0]for k, v in param.itens()}
    
#     # model
#     model_xgb = xgb.XGBRegressor( objective='reg:squarederror',
#                                  n_estimators=hp['n_estimators'],
#                                  eta=hp['eta'],
#                                  max_depth=hp['max_depth'],
#                                  subsample=hp['subsample'],
#                                  colsample_bytee=hp['colsample_bytee'],
#                                  min_child_weight=hp['min_child_weight'] )

#     # performance
#     result = cross_validation( x_training, 2, 'XGBoost Regressor', model_xgb, verbose=False )
#     final_result = pd.concat( [final_result, result] )
# final_result

# %% [markdown]
# ## 8.2 Final Model

# %%
param_tuned = {'n_estimators': [15, 17, 25, 30, 35],
               'eta': [0.01, 0.03],
               'max_depth': [3, 5, 9],
               'subsample': [0.1, 0.5, 0.7],
               'colsample_bytee': [0.3, 0.7, 0.9],
               'min_child_weight': [3, 8, 15]}

MAX_EVAL=2

# %%
# # model
# model_xgb_tuned = xgb.XGBRegressor( objective='reg:squarederror',
#                               n_estimators=param_tuned['n_estimators'],
#                               eta=param_tuned['eta'],
#                               max_depth=param_tuned['max_depth'],
#                               subsample=param_tuned['subsample'],
#                               colsample_bytee=param_tuned['colsample_bytee'],
#                               min_child_weight=param_tuned['min_child_weight'] ).fit( x_train, y_train )

# # prediction
# yhat_xgb_tuned = model_xgb_tuned.predict( x_test )

# # performance
# xgb_result_tuned = ml_error( 'XGBoost Regressor', np.expm1( y_test ), np.expm1( yhat_xgb_tuned ) ) 
# xgb_result_tuned

# pickle.dump(model_xgb_tuned, open( '/home/jocafneto/repositorio/rossmann/model/model_rossmann.pkl', 'wb' ))

# %%
# mpe = mean_percentage_error( np.expm1( y_test ), np.expm1( yhat_xgb_tuned ) )

# %% [markdown]
# # 9.0. PASSO 09 - TRADUÇÃO E INTERPRETAÇÃO DO ERRO

# %%
df9 = X_test[ cols_selected_boruta_full ]

# rescale
df9['sales'] = np.expm1( df9['sales'] )
df9['predictions'] = np.expm1( yhat_xgb_tuned )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [96], in <module>
#       3 # rescale
#       4 df9['sales'] = np.expm1( df9['sales'] )
# ----> 5 df9['predictions'] = np.expm1( yhat_xgb_tuned )
#
# NameError: name 'yhat_xgb_tuned' is not defined

# %% [markdown]
# ## 9.1 Business Performance

# %%
# sum of predictions
df91 = df9[['store', 'predictions']].groupby( 'store' ).sum().reset_index()

# MAE and MAPE
df9_aux1 = df9[['store', 'sales', 'predictions']].groupby( 'store' ).apply( lambda x: mean_absolute_error( x['sales'], x['predictions'] ) ).reset_index().rename( columns={0:'MAE'} )
df9_aux2 = df9[['store', 'sales', 'predictions']].groupby( 'store' ).apply( lambda x: mean_absolute_percentage_error( x['sales'], x['predictions'] ) ).reset_index().rename( columns={0:'MAPE'} )

# merge
df9_aux3 = pd.merge( df9_aux1, df9_aux2, how='inner', on='store' )
df92 = pd.merge( df91, df9_aux3, how='inner', on='store' )

# scenarios
df92['worst_scenario'] = df92['predictions'] - df92['MAE']
df92['best_scenario'] = df92['predictions'] + df92['MAE']

# order columns
df92 = df92[['store', 'predictions', 'worst_scenario', 'best_scenario', 'MAE', 'MAPE']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [97], in <module>
#       1 # sum of predictions
# ----> 2 df91 = df9[['store', 'predictions']].groupby( 'store' ).sum().reset_index()
#       4 # MAE and MAPE
#       5 df9_aux1 = df9[['store', 'sales', 'predictions']].groupby( 'store' ).apply( lambda x: mean_absolute_error( x['sales'], x['predictions'] ) ).reset_index().rename( columns={0:'MAE'} )
#
# File ~/repositorio/DsEmProducao/lib/python3.9/site-packages/pandas/core/frame.py:3512, in DataFrame.__getitem__(self, key)
#    3510     if is_iterator(key):
#    3511         key = list(key)
# -> 3512     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3514 # take() does not accept boolean indexers
#    3515 if getattr(indexer, "dtype", None) == bool:
#
# File ~/repositorio/DsEmProducao/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/repositorio/DsEmProducao/lib/python3.9/site-packages/pandas/core/indexes/base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['predictions'] not in index"

# %%
df92.sort_values( 'MAPE', ascending=False ).head()

# %%
sns.scatterplot( x='store', y='MAPE', data=df92 )

# %% [markdown]
# ## 9.2 Total Performance

# %%
df93 = df92[['predictions', 'worst_scenario', 'best_scenario']].apply( lambda x: np.sum( x ), axis=0 ).reset_index().rename( columns={'index':'Scenarios', 0:'Values'} )
df93['Values'] = df93['Values'].map( 'R${:,.2f}'.format )
df93

# %% [markdown]
# ## 9.3 Machine Learning Performance

# %%
df9['error'] = df9['sales'] - df9['predictions']
df9['error_rate'] = df9['predictions'] / df9['sales']

# %%
plt.subplot( 2, 2, 1 )
sns.lineplot( x='date', y='store', data=df9, label='SALES' )
sns.lineplot( x='date', y='predictions', data=df9, label='PREDICTIONS' )

plt.subplot( 2, 2, 2 )
sns.lineplot( x='date', y='error_rate', data=df9, label='SALES' )
plt.axhline( 1, linestyle='--' )

plt.subplot( 2, 2, 3 )
sns.distplot( df9['error'] )

plt.subplot( 2, 2, 4 )
sns.scatterplot( df9['predictions'], df9['error'] )

# %% [markdown]
# # 10.0. PASSO 10 - DEPLOY MODEL TO PRODUCTION

# %% [markdown]
# ## 10.1 Rossmann Class

# %%
import pickle
import pandas as pd
import numpy as np
import inflection
import math
import datetime

class Rossmann( object ):
    def __init__( self ):
        self.home_path                     = '/home/jocafneto/repositorio/rossmann/'
        self.competition_distance_scaler   = pickle.load( open( self.home_path + 'parameter/competition_distance_scaler.pkl', 'rb' ) )
        self.year_scaler                   = pickle.load( open( self.home_path + 'parameter/year_scaler.pkl', 'rb' ) )
        self.competition_time_month_scaler = pickle.load( open( self.home_path + 'parameter/competition_time_month_scaler.pkl', 'rb' ) )
        self.promo_time_week_scaler        = pickle.load( open( self.home_path + 'parameter/promo_time_week_scaler.pkl', 'rb' ) )
        self.store_type_scaler             = pickle.load( open( self.home_path + 'parameter/store_type_scaler.pkl', 'rb' ) )

        
    def data_cleaning( self, df1 ):

        ## 1.1. Rename Columns
        cols_old = ['Store', 'DayOfWeek', 'Date', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday', 
                    'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth',
                    'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval']

        snakecase = lambda x: inflection.underscore( x )

        cols_new = list( map( snakecase, cols_old ) )

        # rename
        df1.columns = cols_new

        ## 1.3. Data Types
        df1['date'] = pd.to_datetime( df1['date'] )

        ## 1.5. Fillout NA
        #competition_distance        
        df1['competition_distance'] = df1['competition_distance'].apply( lambda x: 200000.0 if math.isnan( x ) else x )

        #competition_open_since_month
        df1['competition_open_since_month'] = df1.apply( lambda x: x['date'].month if math.isnan( x['competition_open_since_month'] ) else x['competition_open_since_month'], axis=1 )

        #competition_open_since_year 
        df1['competition_open_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['competition_open_since_year'] ) else x['competition_open_since_year'], axis=1 )

        #promo2_since_week           
        df1['promo2_since_week'] = df1.apply( lambda x: x['date'].week if math.isnan( x['promo2_since_week'] ) else x['promo2_since_week'], axis=1 )

        #promo2_since_year           
        df1['promo2_since_year'] = df1.apply( lambda x: x['date'].year if math.isnan( x['promo2_since_year'] ) else x['promo2_since_year'], axis=1 )

        #promo_interval              
        month_map = {1: 'Jan',  2: 'Feb',  3: 'Mar',  4: 'Apr',  5: 'May',  6: 'Jun',  7: 'Jul',  8: 'Aug',  9: 'Sep',  10: 'Oct', 11: 'Nov', 12: 'Dec'}

        df1['promo_interval'].fillna(0, inplace=True )

        df1['month_map'] = df1['date'].dt.month.map( month_map )

        df1['is_promo'] = df1[['promo_interval', 'month_map']].apply( lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval'].split( ',' ) else 0, axis=1 )

        ## 1.6. Change Data Types

        # competiton
        df1['competition_open_since_month'] = df1['competition_open_since_month'].astype( int )
        df1['competition_open_since_year'] = df1['competition_open_since_year'].astype( int )

        # promo2
        df1['promo2_since_week'] = df1['promo2_since_week'].astype( int )
        df1['promo2_since_year'] = df1['promo2_since_year'].astype( int )
        
        return df1
    
    def feature_engineering( self, df2 ):
        ## 2.4. Feature Engineering

        # year
        df2['year'] = df2['date'].dt.year

        # month
        df2['month'] = df2['date'].dt.month

        # day
        df2['day'] = df2['date'].dt.day

        # week of year
        df2['week_of_year'] = df2['date'].dt.weekofyear

        # year week
        df2['year_week'] = df2['date'].dt.strftime( '%Y-%W' )

        # competition since
        df2['competition_since'] = df2.apply( lambda x: datetime.datetime( year=x['competition_open_since_year'], month=x['competition_open_since_month'],day=1 ), axis=1 )
        df2['competition_time_month'] = ( ( df2['date'] - df2['competition_since'] )/30 ).apply( lambda x: x.days ).astype( int )

        # promo since
        df2['promo_since'] = df2['promo2_since_year'].astype( str ) + '-' + df2['promo2_since_week'].astype( str )
        df2['promo_since'] = df2['promo_since'].apply( lambda x: datetime.datetime.strptime( x + '-1', '%Y-%W-%w' ) - datetime.timedelta( days=7 ) )
        df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since'] )/7 ).apply( lambda x: x.days ).astype( int )

        # assortment
        df2['assortment'] = df2['assortment'].apply( lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended' )

        # state holiday
        df2['state_holiday'] = df2['state_holiday'].apply( lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' else 'christmas' if x == 'c' else 'regular_day' )

        # 3.0. PASSO 03 - FILTRAGEM DE VARIÁVEIS
        ## 3.1. Filtragem das Linhas
        df2 = df2[df2['open'] != 0]

        ## 3.2. Selecao das Colunas
        cols_drop = ['open', 'promo_interval', 'month_map']
        df2 = df2.drop( cols_drop, axis=1 )
        
        return df2
    
    def data_preparation( self, df5 ):
        ## 5.2 Rescaling
        # competition distance
        df5['competition_distance'] = self.competition_distance_scaler.transform( df5[['competition_distance']].values )

        # competition time month
        df5['competition_time_month'] = self.competition_time_month_scaler.transform( df5[['competition_time_month']].values )

        # promo time week
        df5['promo_time_week'] = self.promo_time_week.transform( df5[['promo_time_week']].values )
        
        # year
        df5['year'] = self.year_scaler.transform( df5[['year']].values )
        
        ### 5.3.1 Encoding
        # state holiday - One Hot Encoding
        df5 = pd.get_dummies(df5, prefix=['state_holiday'], columns=['state_holiday'])

        # store type - Label Encoding
        df5['store_type'] = self.store_type_scaler.transform( df5['store_type'] )
        
        # assortment - Ordinal Encoding
        assortment_dict = {'basic':1, 'extra':2, 'extended':3}
        df5['assortment'] = df5['assortment'].map( assortment_dict )

        ### 5.3.3 Nature Transformation
        # day of week
        df5['day_of_week_sin'] = df5['day_of_week'].apply( lambda x: np.sin( x * ( 2. * np.pi/7) ) )
        df5['day_of_week_cos'] = df5['day_of_week'].apply( lambda x: np.cos( x * ( 2. * np.pi/7) ) )

        # month
        df5['month_sin'] = df5['month'].apply( lambda x: np.sin( x * ( 2. * np.pi/12) ) )
        df5['month_cos'] = df5['month'].apply( lambda x: np.cos( x * ( 2. * np.pi/12) ) )

        # day
        df5['day_sin'] = df5['day'].apply( lambda x: np.sin( x * ( 2. * np.pi/30) ) )
        df5['day_cos'] = df5['day'].apply( lambda x: np.cos( x * ( 2. * np.pi/30) ) )

        # week of year
        df5['week_of_year_sin'] = df5['week_of_year'].apply( lambda x: np.sin( x * ( 2. * np.pi/52) ) )
        df5['week_of_year_cos'] = df5['week_of_year'].apply( lambda x: np.cos( x * ( 2. * np.pi/52) ) )
        
        cols_selected = ['store', 'promo', 'store_type', 'assortment', 'competition_distance',
                         'competition_open_since_month', 'competition_open_since_year', 'promo2',
                         'promo2_since_week', 'promo2_since_year', 'competition_time_month',
                         'promo_time_week', 'day_of_week_sin', 'day_of_week_cos', 'month_sin',
                         'month_cos', 'day_sin', 'day_cos', 'week_of_year_sin', 'week_of_year_cos']
        
        return df5[ cols_selected ]
    
    def get_prediction( self, model, original_data, test_data ):
        # prediction
        pred = model.predict( test_data )
        
        # join pred into original data
        original_data['prediction'] = np.expm1( pred )
        
        return original_data.to_json( oriente='records', data_format='iso' )

# %% [markdown]
# ## 10.2 API Handler

# %%
import pickle
import pandas as pd
from flask import Flask, request, Response
from rossmann.Rossmann import Rossmann

# loading model
model = pickle.load( open( '/home/jocafneto/repositorio/rossmann/model/model_rossmann.pkl', 'rb' ) )

# initialize API
app = Flask( __name__ )

@app.route( '/rossmann/predict', method=['POST'] )
def rossmann_predict():
    test_json = request.get_json()
    
    if test_jason: # there is data
        if isinstance( test_json, dict ): # unique exemple
            test_raw = pd.DataFrame( test_json, index=[0] )
            
        else: # multiple exemples
            test_raw = pd.DataFrame( test_json, columns=test_json[0].keys() )
        
        # Instantiate Rossmann Class
        pipeline = Rossmann()
        
        # data cleaning
        df1 = pipeline.data_cleaning( test_raw )
        
        # feature engineering
        df2 = pipeline.feature_engineering( df1 )
        
        # data preparation
        df3 = pipeline.data_preparation( df2 )
        
        # prediction
        df_response = pipeline.get_prediction( model, test_raw, df3 )
        
        return df_response
        
        
    else:
        return Response( '{}', status=200, mimetype='application/json')
    
if __name__ == '__main__':
    app.run( '0.0.0.0' )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <module>
#       2 import pandas as pd
#       3 from flask import Flask, request, Response
# ----> 4 from rossmann.Rossmann import Rossmann
#       6 # loading model
#       7 model = pickle.load( open( '/home/jocafneto/repositorio/rossmann/model/model_rossmann.pkl', 'rb' ) )
#
# ModuleNotFoundError: No module named 'rossmann'

# %% [markdown]
# ## 10.3 API Tester

# %%
# loading test dataset
df10 = pd.read_csv( '/home/jocafneto/repositorio/rossmann/data/test.csv', low_memory=False )

# %%
# merge test + store
df_test = pd.merge( df10, df_store_raw, how='left', on='Store' )

# choose store for prediction
# df_test = df_test[df_test['Store'].isin( [22, 24, 12, 15, 17] )]
# df_test = df_test[df_test['Store']

# remove closed days
df_test = df_test[df_test['Open'] != 0]
df_test = df_test[~df_test['Open'].isnull()]
df_test = df_test.drop( 'Id', axis=1 )

# %%
df_test.head()
# Out:
#    Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 0      1          4  2015-09-17   1.0      1            0              0         c          a               1270.0                        9.0                    2008.0       0              NaN              NaN              NaN
# 1      3          4  2015-09-17   1.0      1            0              0         a          a              14130.0                       12.0                    2006.0       1             14.0           2011.0  Jan,Apr,Jul,Oct
# 2      7          4  2015-09-17   1.0      1            0              0         a          c              24000.0                        4.0                    2013.0       0              NaN              NaN              NaN
# 3      8          4  2015-09-17   1.0      1            0              0         a          a               7520.0                       10.0                    2014.0       0              NaN              NaN              NaN
# 4      9          4  2015-09-17   1.0      1            0              0         a          c               2030.0                        8.0                    2000.0       0              NaN              NaN              NaN

# %%
# convert DataFrame to json
data = json.dumps( df_test.to_dict( orient='records' ) )

# %%
# API Call
# url = 'http://0.0.0.0:5000/rossmann/predict'
url = 'https://rossmann-model-test27.herokuapp.com/rossmann/predict'
header = {'Content-type': 'application/json' } 
data = data

r = requests.post( url, data=data, headers=header )
print( 'Status Code {}'.format( r.status_code ) )
# Out:
# Status Code 200

# %%
d1 = pd.DataFrame( r.json(), columns=r.json()[0].keys() )

# %%
d2 = d1[['store', 'prediction']].groupby( 'store' ).sum().reset_index()
a = 0.0

for i in range( len( d2 ) ):
    print( 'Store Number {} will sell R${:,.2f} in the next 6 week'.format( d2.loc[i, 'store'], d2.loc[i, 'prediction'] ) )
    a = a + d2.loc[i, 'prediction']
    
print('The sum of Predictions is {:,.2f}'.format(a))
# Out:
# Store Number 1 will sell R$197,525.26 in the next 6 week
# Store Number 3 will sell R$200,393.65 in the next 6 week
# Store Number 7 will sell R$242,371.21 in the next 6 week
# Store Number 8 will sell R$192,256.53 in the next 6 week
# Store Number 9 will sell R$321,552.75 in the next 6 week
# Store Number 10 will sell R$192,741.41 in the next 6 week
# Store Number 11 will sell R$240,342.29 in the next 6 week
# Store Number 12 will sell R$269,394.49 in the next 6 week
# Store Number 13 will sell R$241,186.49 in the next 6 week
# Store Number 14 will sell R$227,937.49 in the next 6 week
# Store Number 15 will sell R$344,029.94 in the next 6 week
# Store Number 16 will sell R$250,769.90 in the next 6 week
# Store Number 19 will sell R$256,224.19 in the next 6 week
# Store Number 20 will sell R$246,412.71 in the next 6 week
# Store Number 21 will sell R$321,226.68 in the next 6 week
# Store Number 22 will sell R$172,753.99 in the next 6 week
# Store Number 23 will sell R$224,289.67 in the next 6 week
# Store Number 24 will sell R$500,808.64 in the next 6 week
# Store Number 25 will sell R$384,821.87 in the next 6 week
# Store Number 27 will sell R$223,849.72 in the next 6 week
# Store Number 29 will sell R$313,075.96 in the next 6 week
# Store Number 30 will sell R$151,134.60 in the next 6 week
# Store Number 31 will sell R$270,404.09 in the next 6 week
# Store Number 32 will sell R$161,934.27 in the next 6 week
# Store Number 33 will sell R$235,253.89 in the next 6 week
# Store Number 35 will sell R$511,528.87 in the next 6 week
# Store Number 36 will sell R$259,939.87 in the next 6 week
# Store Number 38 will sell R$259,887.05 in the next 6 week
# Store Number 39 will sell R$167,464.26 in the next 6 week
# Store Number 40 will sell R$180,300.11 in the next 6 week
# Store Number 41 will sell R$252,860.40 in the next 6 week
# Store Number 42 will sell R$305,151.16 in the next 6 week
# Store Number 43 will sell R$289,119.92 in the next 6 week
# Store Number 45 will sell R$263,229.85 in the next 6 week
# Store Number 46 will sell R$210,901.17 in the next 6 week
# Store Number 47 will sell R$219,817.29 in the next 6 week
# Store Number 48 will sell R$159,864.21 in the next 6 week
# Store Number 49 will sell R$305,059.23 in the next 6 week
# Store Number 50 will sell R$206,236.28 in the next 6 week
# Store Number 51 will sell R$218,123.44 in the next 6 week
# Store Number 52 will sell R$335,814.59 in the next 6 week
# Store Number 53 will sell R$198,466.25 in the next 6 week
# Store Number 56 will sell R$253,169.10 in the next 6 week
# Store Number 58 will sell R$230,172.94 in the next 6 week
# Store Number 61 will sell R$169,534.04 in the next 6 week
# Store Number 62 will sell R$214,854.38 in the next 6 week
# Store Number 63 will sell R$346,198.50 in the next 6 week
# Store Number 64 will sell R$283,311.96 in the next 6 week
# Store Number 66 will sell R$314,963.12 in the next 6 week
# Store Number 67 will sell R$261,507.79 in the next 6 week
# Store Number 68 will sell R$244,757.49 in the next 6 week
# Store Number 69 will sell R$374,977.08 in the next 6 week
# Store Number 70 will sell R$312,330.07 in the next 6 week
# Store Number 71 will sell R$241,897.70 in the next 6 week
# Store Number 72 will sell R$192,638.65 in the next 6 week
# Store Number 73 will sell R$173,290.47 in the next 6 week
# Store Number 74 will sell R$184,447.08 in the next 6 week
# Store Number 75 will sell R$280,309.23 in the next 6 week
# Store Number 76 will sell R$336,727.54 in the next 6 week
# Store Number 77 will sell R$243,152.78 in the next 6 week
# Store Number 79 will sell R$203,728.47 in the next 6 week
# Store Number 80 will sell R$293,058.81 in the next 6 week
# Store Number 81 will sell R$213,460.41 in the next 6 week
# Store Number 82 will sell R$214,043.17 in the next 6 week
# Store Number 83 will sell R$169,706.80 in the next 6 week
# Store Number 84 will sell R$289,175.49 in the next 6 week
# Store Number 86 will sell R$181,719.18 in the next 6 week
# Store Number 89 will sell R$158,392.67 in the next 6 week
# Store Number 90 will sell R$169,740.34 in the next 6 week
# Store Number 91 will sell R$227,274.58 in the next 6 week
# Store Number 92 will sell R$238,853.89 in the next 6 week
# Store Number 93 will sell R$182,165.73 in the next 6 week
# Store Number 94 will sell R$313,280.91 in the next 6 week
# Store Number 98 will sell R$215,637.33 in the next 6 week
# Store Number 99 will sell R$231,738.57 in the next 6 week
# Store Number 100 will sell R$308,220.25 in the next 6 week
# Store Number 101 will sell R$269,123.03 in the next 6 week
# Store Number 102 will sell R$156,176.32 in the next 6 week
# Store Number 105 will sell R$165,406.76 in the next 6 week
# Store Number 107 will sell R$207,933.07 in the next 6 week
# Store Number 108 will sell R$385,614.42 in the next 6 week
# Store Number 109 will sell R$204,429.45 in the next 6 week
# Store Number 110 will sell R$217,405.04 in the next 6 week
# Store Number 111 will sell R$324,831.09 in the next 6 week
# Store Number 112 will sell R$183,059.85 in the next 6 week
# Store Number 113 will sell R$304,130.31 in the next 6 week
# Store Number 115 will sell R$256,316.09 in the next 6 week
# Store Number 117 will sell R$189,739.79 in the next 6 week
# Store Number 118 will sell R$323,038.45 in the next 6 week
# Store Number 119 will sell R$253,032.20 in the next 6 week
# Store Number 120 will sell R$307,208.97 in the next 6 week
# Store Number 122 will sell R$283,419.96 in the next 6 week
# Store Number 124 will sell R$180,167.63 in the next 6 week
# Store Number 126 will sell R$259,897.72 in the next 6 week
# Store Number 127 will sell R$224,704.25 in the next 6 week
# Store Number 128 will sell R$306,990.01 in the next 6 week
# Store Number 129 will sell R$248,252.00 in the next 6 week
# Store Number 130 will sell R$273,805.72 in the next 6 week
# Store Number 131 will sell R$308,116.59 in the next 6 week
# Store Number 132 will sell R$287,747.39 in the next 6 week
# Store Number 135 will sell R$235,873.37 in the next 6 week
# Store Number 136 will sell R$221,009.21 in the next 6 week
# Store Number 137 will sell R$206,418.27 in the next 6 week
# Store Number 139 will sell R$236,326.63 in the next 6 week
# Store Number 140 will sell R$221,931.32 in the next 6 week
# Store Number 141 will sell R$260,638.98 in the next 6 week
# Store Number 142 will sell R$205,670.64 in the next 6 week
# Store Number 143 will sell R$309,912.83 in the next 6 week
# Store Number 144 will sell R$247,743.43 in the next 6 week
# Store Number 145 will sell R$229,727.24 in the next 6 week
# Store Number 146 will sell R$447,170.69 in the next 6 week
# Store Number 147 will sell R$348,629.27 in the next 6 week
# Store Number 149 will sell R$225,374.85 in the next 6 week
# Store Number 150 will sell R$357,167.57 in the next 6 week
# Store Number 152 will sell R$221,664.07 in the next 6 week
# Store Number 153 will sell R$268,497.44 in the next 6 week
# Store Number 154 will sell R$354,505.25 in the next 6 week
# Store Number 155 will sell R$309,788.68 in the next 6 week
# Store Number 157 will sell R$279,989.65 in the next 6 week
# Store Number 158 will sell R$373,112.17 in the next 6 week
# Store Number 159 will sell R$331,297.64 in the next 6 week
# Store Number 160 will sell R$298,443.78 in the next 6 week
# Store Number 161 will sell R$281,769.80 in the next 6 week
# Store Number 162 will sell R$369,989.59 in the next 6 week
# Store Number 164 will sell R$187,261.88 in the next 6 week
# Store Number 165 will sell R$177,505.28 in the next 6 week
# Store Number 166 will sell R$230,980.91 in the next 6 week
# Store Number 168 will sell R$243,355.08 in the next 6 week
# Store Number 169 will sell R$242,778.21 in the next 6 week
# Store Number 170 will sell R$216,989.99 in the next 6 week
# Store Number 171 will sell R$241,733.32 in the next 6 week
# Store Number 172 will sell R$217,094.25 in the next 6 week
# Store Number 174 will sell R$210,253.95 in the next 6 week
# Store Number 175 will sell R$309,203.44 in the next 6 week
# Store Number 176 will sell R$229,169.16 in the next 6 week
# Store Number 179 will sell R$242,776.03 in the next 6 week
# Store Number 180 will sell R$302,635.77 in the next 6 week
# Store Number 181 will sell R$240,248.21 in the next 6 week
# Store Number 182 will sell R$278,570.27 in the next 6 week
# Store Number 183 will sell R$208,727.23 in the next 6 week
# Store Number 184 will sell R$314,877.69 in the next 6 week
# Store Number 186 will sell R$177,282.70 in the next 6 week
# Store Number 187 will sell R$241,734.06 in the next 6 week
# Store Number 188 will sell R$266,181.42 in the next 6 week
# Store Number 189 will sell R$339,917.37 in the next 6 week
# Store Number 190 will sell R$198,262.50 in the next 6 week
# Store Number 191 will sell R$217,754.99 in the next 6 week
# Store Number 192 will sell R$315,472.52 in the next 6 week
# Store Number 193 will sell R$217,544.99 in the next 6 week
# Store Number 194 will sell R$235,181.98 in the next 6 week
# Store Number 195 will sell R$236,115.57 in the next 6 week
# Store Number 197 will sell R$286,382.43 in the next 6 week
# Store Number 199 will sell R$312,603.30 in the next 6 week
# Store Number 200 will sell R$333,783.35 in the next 6 week
# Store Number 201 will sell R$215,514.97 in the next 6 week
# Store Number 202 will sell R$309,478.79 in the next 6 week
# Store Number 204 will sell R$214,749.23 in the next 6 week
# Store Number 206 will sell R$251,747.63 in the next 6 week
# Store Number 207 will sell R$307,752.22 in the next 6 week
# Store Number 209 will sell R$218,862.59 in the next 6 week
# Store Number 210 will sell R$162,457.18 in the next 6 week
# Store Number 212 will sell R$211,808.47 in the next 6 week
# Store Number 213 will sell R$250,240.99 in the next 6 week
# Store Number 214 will sell R$228,555.73 in the next 6 week
# Store Number 215 will sell R$266,560.35 in the next 6 week
# Store Number 216 will sell R$268,029.09 in the next 6 week
# Store Number 217 will sell R$267,727.65 in the next 6 week
# Store Number 218 will sell R$204,477.04 in the next 6 week
# Store Number 219 will sell R$186,639.90 in the next 6 week
# Store Number 220 will sell R$176,224.58 in the next 6 week
# Store Number 221 will sell R$301,820.02 in the next 6 week
# Store Number 224 will sell R$257,117.36 in the next 6 week
# Store Number 226 will sell R$233,871.37 in the next 6 week
# Store Number 227 will sell R$230,309.23 in the next 6 week
# Store Number 228 will sell R$334,900.49 in the next 6 week
# Store Number 229 will sell R$334,899.98 in the next 6 week
# Store Number 230 will sell R$318,200.40 in the next 6 week
# Store Number 231 will sell R$270,998.45 in the next 6 week
# Store Number 233 will sell R$277,745.28 in the next 6 week
# Store Number 234 will sell R$396,877.99 in the next 6 week
# Store Number 235 will sell R$261,995.43 in the next 6 week
# Store Number 238 will sell R$224,313.97 in the next 6 week
# Store Number 239 will sell R$287,036.38 in the next 6 week
# Store Number 241 will sell R$299,197.96 in the next 6 week
# Store Number 242 will sell R$210,139.27 in the next 6 week
# Store Number 243 will sell R$213,339.28 in the next 6 week
# Store Number 244 will sell R$242,419.44 in the next 6 week
# Store Number 245 will sell R$256,773.74 in the next 6 week
# Store Number 246 will sell R$320,078.98 in the next 6 week
# Store Number 247 will sell R$254,872.38 in the next 6 week
# Store Number 248 will sell R$257,395.19 in the next 6 week
# Store Number 249 will sell R$307,515.32 in the next 6 week
# Store Number 250 will sell R$276,693.21 in the next 6 week
# Store Number 251 will sell R$304,752.47 in the next 6 week
# Store Number 252 will sell R$340,809.82 in the next 6 week
# Store Number 253 will sell R$192,580.02 in the next 6 week
# Store Number 254 will sell R$197,289.22 in the next 6 week
# Store Number 255 will sell R$328,624.22 in the next 6 week
# Store Number 256 will sell R$173,496.93 in the next 6 week
# Store Number 258 will sell R$225,482.96 in the next 6 week
# Store Number 259 will sell R$371,287.10 in the next 6 week
# Store Number 262 will sell R$698,512.75 in the next 6 week
# Store Number 263 will sell R$158,862.36 in the next 6 week
# Store Number 265 will sell R$165,463.33 in the next 6 week
# Store Number 267 will sell R$366,085.02 in the next 6 week
# Store Number 268 will sell R$218,969.83 in the next 6 week
# Store Number 269 will sell R$228,349.22 in the next 6 week
# Store Number 272 will sell R$185,796.13 in the next 6 week
# Store Number 273 will sell R$230,897.80 in the next 6 week
# Store Number 274 will sell R$220,325.69 in the next 6 week
# Store Number 275 will sell R$258,745.47 in the next 6 week
# Store Number 277 will sell R$344,377.57 in the next 6 week
# Store Number 278 will sell R$262,952.32 in the next 6 week
# Store Number 279 will sell R$335,863.50 in the next 6 week
# Store Number 280 will sell R$232,220.54 in the next 6 week
# Store Number 281 will sell R$283,556.77 in the next 6 week
# Store Number 283 will sell R$191,615.43 in the next 6 week
# Store Number 284 will sell R$240,599.91 in the next 6 week
# Store Number 285 will sell R$210,581.69 in the next 6 week
# Store Number 287 will sell R$268,989.91 in the next 6 week
# Store Number 288 will sell R$254,789.66 in the next 6 week
# Store Number 289 will sell R$275,697.97 in the next 6 week
# Store Number 290 will sell R$255,772.17 in the next 6 week
# Store Number 294 will sell R$185,925.33 in the next 6 week
# Store Number 295 will sell R$232,126.71 in the next 6 week
# Store Number 296 will sell R$184,646.39 in the next 6 week
# Store Number 297 will sell R$231,522.07 in the next 6 week
# Store Number 298 will sell R$330,360.20 in the next 6 week
# Store Number 299 will sell R$353,146.62 in the next 6 week
# Store Number 300 will sell R$227,370.33 in the next 6 week
# Store Number 301 will sell R$207,319.96 in the next 6 week
# Store Number 302 will sell R$223,456.12 in the next 6 week
# Store Number 303 will sell R$206,332.52 in the next 6 week
# Store Number 304 will sell R$219,635.01 in the next 6 week
# Store Number 305 will sell R$261,199.60 in the next 6 week
# Store Number 306 will sell R$165,106.83 in the next 6 week
# Store Number 308 will sell R$276,235.47 in the next 6 week
# Store Number 309 will sell R$315,809.85 in the next 6 week
# Store Number 310 will sell R$213,988.69 in the next 6 week
# Store Number 311 will sell R$203,854.05 in the next 6 week
# Store Number 312 will sell R$298,402.47 in the next 6 week
# Store Number 314 will sell R$212,248.82 in the next 6 week
# Store Number 315 will sell R$237,332.16 in the next 6 week
# Store Number 316 will sell R$370,404.77 in the next 6 week
# Store Number 317 will sell R$245,766.38 in the next 6 week
# Store Number 319 will sell R$242,026.79 in the next 6 week
# Store Number 320 will sell R$249,002.17 in the next 6 week
# Store Number 323 will sell R$270,849.42 in the next 6 week
# Store Number 325 will sell R$276,630.18 in the next 6 week
# Store Number 326 will sell R$237,485.98 in the next 6 week
# Store Number 328 will sell R$208,405.06 in the next 6 week
# Store Number 329 will sell R$290,919.89 in the next 6 week
# Store Number 330 will sell R$185,450.69 in the next 6 week
# Store Number 331 will sell R$164,611.91 in the next 6 week
# Store Number 333 will sell R$320,797.50 in the next 6 week
# Store Number 334 will sell R$241,967.04 in the next 6 week
# Store Number 335 will sell R$393,545.23 in the next 6 week
# Store Number 336 will sell R$295,953.35 in the next 6 week
# Store Number 337 will sell R$212,658.80 in the next 6 week
# Store Number 338 will sell R$300,007.12 in the next 6 week
# Store Number 339 will sell R$188,868.85 in the next 6 week
# Store Number 340 will sell R$225,607.40 in the next 6 week
# Store Number 341 will sell R$198,076.64 in the next 6 week
# Store Number 342 will sell R$270,951.43 in the next 6 week
# Store Number 343 will sell R$238,973.74 in the next 6 week
# Store Number 344 will sell R$286,838.25 in the next 6 week
# Store Number 345 will sell R$182,281.39 in the next 6 week
# Store Number 346 will sell R$225,073.82 in the next 6 week
# Store Number 347 will sell R$249,284.28 in the next 6 week
# Store Number 348 will sell R$218,974.73 in the next 6 week
# Store Number 350 will sell R$270,096.15 in the next 6 week
# Store Number 351 will sell R$221,438.84 in the next 6 week
# Store Number 352 will sell R$313,937.03 in the next 6 week
# Store Number 353 will sell R$289,264.75 in the next 6 week
# Store Number 354 will sell R$335,300.37 in the next 6 week
# Store Number 355 will sell R$271,368.41 in the next 6 week
# Store Number 356 will sell R$275,413.46 in the next 6 week
# Store Number 358 will sell R$282,454.08 in the next 6 week
# Store Number 359 will sell R$308,882.93 in the next 6 week
# Store Number 362 will sell R$279,680.24 in the next 6 week
# Store Number 364 will sell R$156,620.43 in the next 6 week
# Store Number 365 will sell R$238,745.26 in the next 6 week
# Store Number 367 will sell R$246,129.02 in the next 6 week
# Store Number 368 will sell R$361,979.31 in the next 6 week
# Store Number 369 will sell R$283,197.31 in the next 6 week
# Store Number 370 will sell R$358,196.89 in the next 6 week
# Store Number 371 will sell R$240,137.60 in the next 6 week
# Store Number 372 will sell R$261,178.98 in the next 6 week
# Store Number 373 will sell R$253,806.44 in the next 6 week
# Store Number 377 will sell R$278,491.61 in the next 6 week
# Store Number 378 will sell R$233,698.96 in the next 6 week
# Store Number 379 will sell R$199,930.01 in the next 6 week
# Store Number 380 will sell R$269,001.52 in the next 6 week
# Store Number 383 will sell R$320,625.40 in the next 6 week
# Store Number 385 will sell R$300,663.47 in the next 6 week
# Store Number 386 will sell R$316,122.41 in the next 6 week
# Store Number 387 will sell R$290,587.61 in the next 6 week
# Store Number 388 will sell R$288,245.00 in the next 6 week
# Store Number 389 will sell R$323,899.55 in the next 6 week
# Store Number 391 will sell R$203,731.76 in the next 6 week
# Store Number 392 will sell R$238,518.03 in the next 6 week
# Store Number 393 will sell R$339,812.70 in the next 6 week
# Store Number 394 will sell R$329,491.65 in the next 6 week
# Store Number 395 will sell R$218,285.70 in the next 6 week
# Store Number 397 will sell R$216,876.70 in the next 6 week
# Store Number 398 will sell R$249,489.29 in the next 6 week
# Store Number 399 will sell R$211,564.99 in the next 6 week
# Store Number 403 will sell R$221,045.63 in the next 6 week
# Store Number 404 will sell R$199,252.81 in the next 6 week
# Store Number 405 will sell R$203,878.71 in the next 6 week
# Store Number 406 will sell R$363,833.61 in the next 6 week
# Store Number 407 will sell R$161,373.46 in the next 6 week
# Store Number 408 will sell R$246,198.14 in the next 6 week
# Store Number 409 will sell R$267,935.27 in the next 6 week
# Store Number 410 will sell R$236,188.89 in the next 6 week
# Store Number 411 will sell R$351,986.64 in the next 6 week
# Store Number 412 will sell R$369,173.79 in the next 6 week
# Store Number 413 will sell R$250,597.05 in the next 6 week
# Store Number 414 will sell R$271,458.45 in the next 6 week
# Store Number 415 will sell R$320,572.07 in the next 6 week
# Store Number 416 will sell R$273,127.26 in the next 6 week
# Store Number 417 will sell R$201,477.81 in the next 6 week
# Store Number 418 will sell R$218,742.40 in the next 6 week
# Store Number 420 will sell R$274,475.07 in the next 6 week
# Store Number 421 will sell R$301,551.94 in the next 6 week
# Store Number 422 will sell R$225,612.42 in the next 6 week
# Store Number 424 will sell R$368,539.79 in the next 6 week
# Store Number 425 will sell R$284,912.22 in the next 6 week
# Store Number 426 will sell R$204,517.01 in the next 6 week
# Store Number 427 will sell R$231,382.95 in the next 6 week
# Store Number 428 will sell R$211,442.54 in the next 6 week
# Store Number 429 will sell R$247,188.52 in the next 6 week
# Store Number 430 will sell R$332,118.76 in the next 6 week
# Store Number 431 will sell R$369,956.37 in the next 6 week
# Store Number 432 will sell R$257,580.38 in the next 6 week
# Store Number 433 will sell R$238,831.28 in the next 6 week
# Store Number 434 will sell R$195,345.61 in the next 6 week
# Store Number 435 will sell R$186,802.18 in the next 6 week
# Store Number 440 will sell R$227,137.28 in the next 6 week
# Store Number 441 will sell R$295,108.49 in the next 6 week
# Store Number 442 will sell R$245,014.77 in the next 6 week
# Store Number 445 will sell R$237,550.95 in the next 6 week
# Store Number 446 will sell R$235,088.97 in the next 6 week
# Store Number 447 will sell R$230,197.64 in the next 6 week
# Store Number 448 will sell R$265,250.75 in the next 6 week
# Store Number 449 will sell R$314,652.59 in the next 6 week
# Store Number 450 will sell R$297,605.13 in the next 6 week
# Store Number 451 will sell R$221,050.98 in the next 6 week
# Store Number 452 will sell R$235,575.54 in the next 6 week
# Store Number 453 will sell R$265,493.65 in the next 6 week
# Store Number 455 will sell R$312,363.70 in the next 6 week
# Store Number 456 will sell R$231,159.34 in the next 6 week
# Store Number 457 will sell R$240,584.29 in the next 6 week
# Store Number 458 will sell R$293,069.98 in the next 6 week
# Store Number 459 will sell R$187,020.79 in the next 6 week
# Store Number 461 will sell R$229,567.73 in the next 6 week
# Store Number 463 will sell R$191,131.82 in the next 6 week
# Store Number 465 will sell R$352,723.46 in the next 6 week
# Store Number 466 will sell R$340,957.18 in the next 6 week
# Store Number 467 will sell R$300,398.39 in the next 6 week
# Store Number 468 will sell R$314,426.84 in the next 6 week
# Store Number 470 will sell R$248,072.42 in the next 6 week
# Store Number 471 will sell R$264,812.16 in the next 6 week
# Store Number 472 will sell R$267,185.34 in the next 6 week
# Store Number 473 will sell R$166,699.82 in the next 6 week
# Store Number 475 will sell R$160,393.50 in the next 6 week
# Store Number 477 will sell R$234,500.25 in the next 6 week
# Store Number 481 will sell R$257,205.85 in the next 6 week
# Store Number 484 will sell R$273,419.79 in the next 6 week
# Store Number 485 will sell R$253,395.12 in the next 6 week
# Store Number 486 will sell R$179,553.35 in the next 6 week
# Store Number 487 will sell R$293,356.64 in the next 6 week
# Store Number 488 will sell R$183,310.69 in the next 6 week
# Store Number 490 will sell R$209,775.54 in the next 6 week
# Store Number 491 will sell R$264,271.03 in the next 6 week
# Store Number 492 will sell R$236,355.15 in the next 6 week
# Store Number 493 will sell R$313,491.93 in the next 6 week
# Store Number 495 will sell R$244,700.74 in the next 6 week
# Store Number 497 will sell R$237,008.23 in the next 6 week
# Store Number 498 will sell R$185,946.23 in the next 6 week
# Store Number 499 will sell R$227,286.56 in the next 6 week
# Store Number 500 will sell R$232,239.49 in the next 6 week
# Store Number 501 will sell R$211,810.98 in the next 6 week
# Store Number 502 will sell R$305,389.95 in the next 6 week
# Store Number 504 will sell R$290,798.60 in the next 6 week
# Store Number 505 will sell R$170,517.49 in the next 6 week
# Store Number 506 will sell R$211,101.78 in the next 6 week
# Store Number 507 will sell R$321,028.70 in the next 6 week
# Store Number 508 will sell R$279,185.15 in the next 6 week
# Store Number 509 will sell R$196,397.26 in the next 6 week
# Store Number 510 will sell R$232,509.11 in the next 6 week
# Store Number 511 will sell R$200,461.05 in the next 6 week
# Store Number 512 will sell R$265,503.33 in the next 6 week
# Store Number 514 will sell R$254,388.23 in the next 6 week
# Store Number 515 will sell R$296,901.89 in the next 6 week
# Store Number 516 will sell R$434,852.79 in the next 6 week
# Store Number 517 will sell R$217,435.14 in the next 6 week
# Store Number 518 will sell R$307,200.54 in the next 6 week
# Store Number 519 will sell R$237,603.00 in the next 6 week
# Store Number 520 will sell R$186,937.76 in the next 6 week
# Store Number 521 will sell R$219,323.58 in the next 6 week
# Store Number 522 will sell R$332,547.12 in the next 6 week
# Store Number 524 will sell R$277,646.51 in the next 6 week
# Store Number 527 will sell R$393,579.22 in the next 6 week
# Store Number 528 will sell R$308,439.21 in the next 6 week
# Store Number 529 will sell R$318,596.98 in the next 6 week
# Store Number 530 will sell R$219,562.88 in the next 6 week
# Store Number 531 will sell R$193,117.65 in the next 6 week
# Store Number 532 will sell R$284,458.12 in the next 6 week
# Store Number 533 will sell R$294,661.39 in the next 6 week
# Store Number 534 will sell R$285,131.39 in the next 6 week
# Store Number 535 will sell R$239,701.66 in the next 6 week
# Store Number 536 will sell R$315,657.50 in the next 6 week
# Store Number 537 will sell R$236,218.38 in the next 6 week
# Store Number 538 will sell R$145,789.29 in the next 6 week
# Store Number 539 will sell R$202,421.29 in the next 6 week
# Store Number 540 will sell R$260,450.43 in the next 6 week
# Store Number 541 will sell R$279,417.32 in the next 6 week
# Store Number 542 will sell R$163,580.40 in the next 6 week
# Store Number 543 will sell R$126,571.23 in the next 6 week
# Store Number 545 will sell R$227,495.70 in the next 6 week
# Store Number 547 will sell R$246,978.48 in the next 6 week
# Store Number 548 will sell R$222,848.20 in the next 6 week
# Store Number 549 will sell R$163,026.51 in the next 6 week
# Store Number 550 will sell R$204,281.70 in the next 6 week
# Store Number 551 will sell R$180,038.26 in the next 6 week
# Store Number 552 will sell R$192,549.45 in the next 6 week
# Store Number 553 will sell R$254,426.06 in the next 6 week
# Store Number 554 will sell R$194,580.40 in the next 6 week
# Store Number 555 will sell R$176,651.51 in the next 6 week
# Store Number 557 will sell R$130,888.59 in the next 6 week
# Store Number 558 will sell R$125,681.76 in the next 6 week
# Store Number 561 will sell R$255,575.70 in the next 6 week
# Store Number 562 will sell R$465,386.52 in the next 6 week
# Store Number 563 will sell R$126,951.47 in the next 6 week
# Store Number 564 will sell R$220,033.03 in the next 6 week
# Store Number 565 will sell R$176,113.49 in the next 6 week
# Store Number 566 will sell R$164,032.90 in the next 6 week
# Store Number 567 will sell R$201,442.91 in the next 6 week
# Store Number 568 will sell R$209,094.32 in the next 6 week
# Store Number 570 will sell R$120,545.78 in the next 6 week
# Store Number 571 will sell R$244,448.94 in the next 6 week
# Store Number 572 will sell R$318,982.91 in the next 6 week
# Store Number 573 will sell R$138,499.28 in the next 6 week
# Store Number 574 will sell R$260,170.58 in the next 6 week
# Store Number 575 will sell R$168,396.64 in the next 6 week
# Store Number 577 will sell R$199,358.80 in the next 6 week
# Store Number 578 will sell R$275,398.65 in the next 6 week
# Store Number 579 will sell R$234,013.18 in the next 6 week
# Store Number 580 will sell R$232,893.26 in the next 6 week
# Store Number 581 will sell R$163,294.38 in the next 6 week
# Store Number 582 will sell R$172,926.65 in the next 6 week
# Store Number 584 will sell R$211,912.13 in the next 6 week
# Store Number 585 will sell R$228,947.29 in the next 6 week
# Store Number 586 will sell R$226,463.92 in the next 6 week
# Store Number 587 will sell R$293,319.56 in the next 6 week
# Store Number 588 will sell R$273,275.59 in the next 6 week
# Store Number 589 will sell R$181,616.26 in the next 6 week
# Store Number 590 will sell R$213,263.90 in the next 6 week
# Store Number 591 will sell R$192,852.10 in the next 6 week
# Store Number 592 will sell R$124,528.14 in the next 6 week
# Store Number 593 will sell R$231,815.00 in the next 6 week
# Store Number 597 will sell R$128,910.85 in the next 6 week
# Store Number 598 will sell R$181,707.48 in the next 6 week
# Store Number 600 will sell R$259,057.57 in the next 6 week
# Store Number 601 will sell R$202,585.23 in the next 6 week
# Store Number 602 will sell R$176,443.34 in the next 6 week
# Store Number 603 will sell R$180,093.07 in the next 6 week
# Store Number 604 will sell R$232,749.05 in the next 6 week
# Store Number 605 will sell R$220,927.82 in the next 6 week
# Store Number 610 will sell R$153,138.35 in the next 6 week
# Store Number 611 will sell R$166,299.36 in the next 6 week
# Store Number 612 will sell R$285,031.64 in the next 6 week
# Store Number 615 will sell R$218,013.26 in the next 6 week
# Store Number 616 will sell R$238,406.87 in the next 6 week
# Store Number 618 will sell R$252,368.60 in the next 6 week
# Store Number 619 will sell R$135,935.14 in the next 6 week
# Store Number 620 will sell R$213,683.19 in the next 6 week
# Store Number 621 will sell R$169,832.15 in the next 6 week
# Store Number 622 will sell R$143,841.67 in the next 6 week
# Store Number 623 will sell R$188,061.74 in the next 6 week
# Store Number 624 will sell R$191,478.06 in the next 6 week
# Store Number 625 will sell R$168,208.88 in the next 6 week
# Store Number 627 will sell R$241,283.65 in the next 6 week
# Store Number 628 will sell R$184,264.78 in the next 6 week
# Store Number 629 will sell R$174,336.68 in the next 6 week
# Store Number 631 will sell R$222,700.64 in the next 6 week
# Store Number 632 will sell R$184,805.38 in the next 6 week
# Store Number 633 will sell R$188,903.66 in the next 6 week
# Store Number 636 will sell R$175,608.69 in the next 6 week
# Store Number 637 will sell R$287,124.67 in the next 6 week
# Store Number 638 will sell R$222,273.26 in the next 6 week
# Store Number 639 will sell R$126,570.80 in the next 6 week
# Store Number 640 will sell R$290,268.01 in the next 6 week
# Store Number 641 will sell R$179,326.42 in the next 6 week
# Store Number 642 will sell R$213,845.55 in the next 6 week
# Store Number 643 will sell R$181,777.42 in the next 6 week
# Store Number 644 will sell R$223,183.30 in the next 6 week
# Store Number 645 will sell R$183,522.81 in the next 6 week
# Store Number 646 will sell R$155,457.81 in the next 6 week
# Store Number 647 will sell R$186,008.55 in the next 6 week
# Store Number 650 will sell R$143,173.26 in the next 6 week
# Store Number 651 will sell R$166,861.27 in the next 6 week
# Store Number 653 will sell R$259,990.55 in the next 6 week
# Store Number 655 will sell R$241,909.63 in the next 6 week
# Store Number 656 will sell R$153,218.43 in the next 6 week
# Store Number 657 will sell R$171,111.69 in the next 6 week
# Store Number 658 will sell R$267,765.87 in the next 6 week
# Store Number 659 will sell R$198,491.16 in the next 6 week
# Store Number 660 will sell R$109,770.52 in the next 6 week
# Store Number 661 will sell R$233,816.99 in the next 6 week
# Store Number 662 will sell R$265,645.04 in the next 6 week
# Store Number 663 will sell R$159,223.07 in the next 6 week
# Store Number 665 will sell R$154,722.21 in the next 6 week
# Store Number 666 will sell R$213,722.55 in the next 6 week
# Store Number 667 will sell R$263,570.58 in the next 6 week
# Store Number 669 will sell R$161,708.52 in the next 6 week
# Store Number 670 will sell R$171,484.65 in the next 6 week
# Store Number 671 will sell R$247,779.14 in the next 6 week
# Store Number 673 will sell R$207,644.60 in the next 6 week
# Store Number 674 will sell R$162,049.49 in the next 6 week
# Store Number 675 will sell R$148,225.91 in the next 6 week
# Store Number 676 will sell R$255,677.25 in the next 6 week
# Store Number 677 will sell R$204,663.29 in the next 6 week
# Store Number 678 will sell R$215,360.52 in the next 6 week
# Store Number 680 will sell R$185,601.40 in the next 6 week
# Store Number 681 will sell R$131,804.68 in the next 6 week
# Store Number 684 will sell R$226,702.68 in the next 6 week
# Store Number 685 will sell R$187,064.77 in the next 6 week
# Store Number 687 will sell R$253,013.22 in the next 6 week
# Store Number 689 will sell R$204,935.98 in the next 6 week
# Store Number 690 will sell R$167,757.60 in the next 6 week
# Store Number 691 will sell R$277,632.40 in the next 6 week
# Store Number 692 will sell R$181,436.65 in the next 6 week
# Store Number 693 will sell R$216,165.44 in the next 6 week
# Store Number 694 will sell R$176,132.58 in the next 6 week
# Store Number 695 will sell R$141,136.04 in the next 6 week
# Store Number 696 will sell R$187,150.13 in the next 6 week
# Store Number 697 will sell R$249,999.26 in the next 6 week
# Store Number 699 will sell R$176,586.65 in the next 6 week
# Store Number 700 will sell R$156,496.48 in the next 6 week
# Store Number 701 will sell R$192,231.19 in the next 6 week
# Store Number 702 will sell R$151,217.68 in the next 6 week
# Store Number 703 will sell R$102,806.91 in the next 6 week
# Store Number 705 will sell R$175,827.04 in the next 6 week
# Store Number 706 will sell R$158,206.28 in the next 6 week
# Store Number 707 will sell R$255,385.25 in the next 6 week
# Store Number 710 will sell R$180,324.23 in the next 6 week
# Store Number 711 will sell R$199,739.08 in the next 6 week
# Store Number 712 will sell R$155,546.30 in the next 6 week
# Store Number 713 will sell R$151,579.54 in the next 6 week
# Store Number 714 will sell R$197,590.05 in the next 6 week
# Store Number 716 will sell R$209,685.79 in the next 6 week
# Store Number 717 will sell R$257,704.99 in the next 6 week
# Store Number 718 will sell R$158,931.12 in the next 6 week
# Store Number 719 will sell R$243,283.29 in the next 6 week
# Store Number 720 will sell R$198,090.96 in the next 6 week
# Store Number 721 will sell R$191,640.52 in the next 6 week
# Store Number 722 will sell R$169,460.83 in the next 6 week
# Store Number 723 will sell R$223,420.55 in the next 6 week
# Store Number 724 will sell R$244,689.05 in the next 6 week
# Store Number 725 will sell R$243,522.55 in the next 6 week
# Store Number 727 will sell R$158,561.03 in the next 6 week
# Store Number 728 will sell R$185,504.74 in the next 6 week
# Store Number 729 will sell R$278,999.12 in the next 6 week
# Store Number 731 will sell R$145,440.61 in the next 6 week
# Store Number 732 will sell R$212,014.65 in the next 6 week
# Store Number 733 will sell R$484,909.03 in the next 6 week
# Store Number 734 will sell R$142,026.10 in the next 6 week
# Store Number 736 will sell R$221,615.70 in the next 6 week
# Store Number 737 will sell R$138,276.60 in the next 6 week
# Store Number 738 will sell R$269,681.36 in the next 6 week
# Store Number 739 will sell R$292,551.70 in the next 6 week
# Store Number 740 will sell R$222,587.25 in the next 6 week
# Store Number 741 will sell R$259,993.91 in the next 6 week
# Store Number 742 will sell R$259,528.36 in the next 6 week
# Store Number 744 will sell R$165,023.31 in the next 6 week
# Store Number 746 will sell R$268,655.20 in the next 6 week
# Store Number 748 will sell R$195,094.83 in the next 6 week
# Store Number 749 will sell R$132,317.94 in the next 6 week
# Store Number 750 will sell R$230,942.34 in the next 6 week
# Store Number 751 will sell R$136,635.68 in the next 6 week
# Store Number 752 will sell R$162,118.79 in the next 6 week
# Store Number 753 will sell R$315,879.34 in the next 6 week
# Store Number 756 will sell R$241,947.44 in the next 6 week
# Store Number 757 will sell R$183,722.61 in the next 6 week
# Store Number 758 will sell R$177,202.24 in the next 6 week
# Store Number 759 will sell R$159,771.99 in the next 6 week
# Store Number 762 will sell R$167,160.27 in the next 6 week
# Store Number 763 will sell R$222,537.31 in the next 6 week
# Store Number 764 will sell R$127,285.51 in the next 6 week
# Store Number 765 will sell R$294,274.78 in the next 6 week
# Store Number 766 will sell R$218,406.03 in the next 6 week
# Store Number 767 will sell R$173,316.05 in the next 6 week
# Store Number 768 will sell R$233,224.30 in the next 6 week
# Store Number 769 will sell R$329,711.04 in the next 6 week
# Store Number 770 will sell R$150,827.97 in the next 6 week
# Store Number 771 will sell R$150,264.22 in the next 6 week
# Store Number 772 will sell R$187,890.48 in the next 6 week
# Store Number 773 will sell R$143,704.48 in the next 6 week
# Store Number 774 will sell R$165,269.04 in the next 6 week
# Store Number 775 will sell R$278,168.90 in the next 6 week
# Store Number 776 will sell R$183,169.06 in the next 6 week
# Store Number 777 will sell R$168,506.66 in the next 6 week
# Store Number 778 will sell R$129,714.67 in the next 6 week
# Store Number 782 will sell R$205,871.07 in the next 6 week
# Store Number 784 will sell R$141,989.47 in the next 6 week
# Store Number 785 will sell R$207,115.19 in the next 6 week
# Store Number 789 will sell R$132,024.86 in the next 6 week
# Store Number 790 will sell R$258,225.84 in the next 6 week
# Store Number 791 will sell R$173,214.53 in the next 6 week
# Store Number 792 will sell R$201,227.72 in the next 6 week
# Store Number 793 will sell R$160,717.09 in the next 6 week
# Store Number 795 will sell R$191,528.19 in the next 6 week
# Store Number 796 will sell R$178,264.23 in the next 6 week
# Store Number 797 will sell R$139,300.43 in the next 6 week
# Store Number 799 will sell R$190,614.26 in the next 6 week
# Store Number 800 will sell R$223,656.99 in the next 6 week
# Store Number 801 will sell R$227,392.53 in the next 6 week
# Store Number 802 will sell R$216,890.55 in the next 6 week
# Store Number 803 will sell R$157,586.43 in the next 6 week
# Store Number 804 will sell R$184,410.88 in the next 6 week
# Store Number 805 will sell R$149,184.29 in the next 6 week
# Store Number 806 will sell R$196,348.37 in the next 6 week
# Store Number 807 will sell R$183,645.45 in the next 6 week
# Store Number 809 will sell R$255,286.87 in the next 6 week
# Store Number 810 will sell R$235,957.01 in the next 6 week
# Store Number 811 will sell R$154,554.42 in the next 6 week
# Store Number 813 will sell R$145,343.96 in the next 6 week
# Store Number 815 will sell R$213,928.56 in the next 6 week
# Store Number 816 will sell R$222,927.06 in the next 6 week
# Store Number 818 will sell R$199,614.19 in the next 6 week
# Store Number 819 will sell R$186,058.63 in the next 6 week
# Store Number 820 will sell R$196,281.98 in the next 6 week
# Store Number 822 will sell R$241,520.46 in the next 6 week
# Store Number 823 will sell R$182,585.27 in the next 6 week
# Store Number 824 will sell R$158,254.83 in the next 6 week
# Store Number 825 will sell R$134,346.98 in the next 6 week
# Store Number 826 will sell R$202,232.44 in the next 6 week
# Store Number 829 will sell R$207,181.72 in the next 6 week
# Store Number 831 will sell R$171,714.90 in the next 6 week
# Store Number 832 will sell R$197,348.62 in the next 6 week
# Store Number 833 will sell R$287,692.93 in the next 6 week
# Store Number 835 will sell R$117,193.31 in the next 6 week
# Store Number 837 will sell R$159,003.73 in the next 6 week
# Store Number 840 will sell R$152,504.85 in the next 6 week
# Store Number 842 will sell R$363,772.66 in the next 6 week
# Store Number 844 will sell R$155,255.16 in the next 6 week
# Store Number 845 will sell R$163,485.55 in the next 6 week
# Store Number 846 will sell R$316,376.69 in the next 6 week
# Store Number 847 will sell R$220,055.08 in the next 6 week
# Store Number 848 will sell R$230,612.11 in the next 6 week
# Store Number 849 will sell R$272,036.06 in the next 6 week
# Store Number 850 will sell R$184,728.58 in the next 6 week
# Store Number 851 will sell R$186,468.35 in the next 6 week
# Store Number 852 will sell R$201,068.68 in the next 6 week
# Store Number 853 will sell R$183,496.75 in the next 6 week
# Store Number 855 will sell R$170,446.19 in the next 6 week
# Store Number 856 will sell R$178,602.97 in the next 6 week
# Store Number 857 will sell R$165,691.32 in the next 6 week
# Store Number 858 will sell R$118,306.63 in the next 6 week
# Store Number 859 will sell R$193,195.47 in the next 6 week
# Store Number 860 will sell R$227,761.27 in the next 6 week
# Store Number 861 will sell R$170,273.47 in the next 6 week
# Store Number 862 will sell R$238,862.20 in the next 6 week
# Store Number 863 will sell R$199,288.95 in the next 6 week
# Store Number 864 will sell R$137,095.94 in the next 6 week
# Store Number 865 will sell R$242,962.75 in the next 6 week
# Store Number 866 will sell R$171,512.00 in the next 6 week
# Store Number 867 will sell R$251,482.84 in the next 6 week
# Store Number 868 will sell R$209,206.83 in the next 6 week
# Store Number 871 will sell R$237,087.58 in the next 6 week
# Store Number 872 will sell R$163,743.96 in the next 6 week
# Store Number 874 will sell R$142,527.73 in the next 6 week
# Store Number 875 will sell R$132,175.72 in the next 6 week
# Store Number 877 will sell R$189,572.96 in the next 6 week
# Store Number 879 will sell R$141,828.55 in the next 6 week
# Store Number 880 will sell R$186,362.21 in the next 6 week
# Store Number 881 will sell R$131,652.74 in the next 6 week
# Store Number 882 will sell R$164,558.45 in the next 6 week
# Store Number 883 will sell R$121,107.00 in the next 6 week
# Store Number 884 will sell R$228,256.54 in the next 6 week
# Store Number 885 will sell R$121,685.65 in the next 6 week
# Store Number 886 will sell R$184,003.13 in the next 6 week
# Store Number 887 will sell R$191,702.18 in the next 6 week
# Store Number 888 will sell R$184,110.19 in the next 6 week
# Store Number 890 will sell R$138,693.29 in the next 6 week
# Store Number 891 will sell R$194,164.65 in the next 6 week
# Store Number 893 will sell R$144,716.55 in the next 6 week
# Store Number 894 will sell R$160,162.21 in the next 6 week
# Store Number 895 will sell R$202,948.36 in the next 6 week
# Store Number 896 will sell R$175,872.93 in the next 6 week
# Store Number 897 will sell R$157,202.59 in the next 6 week
# Store Number 900 will sell R$128,566.80 in the next 6 week
# Store Number 901 will sell R$201,315.56 in the next 6 week
# Store Number 902 will sell R$131,751.08 in the next 6 week
# Store Number 903 will sell R$275,199.85 in the next 6 week
# Store Number 904 will sell R$235,082.93 in the next 6 week
# Store Number 905 will sell R$168,490.91 in the next 6 week
# Store Number 906 will sell R$162,379.22 in the next 6 week
# Store Number 907 will sell R$174,132.20 in the next 6 week
# Store Number 908 will sell R$139,361.20 in the next 6 week
# Store Number 909 will sell R$265,399.31 in the next 6 week
# Store Number 911 will sell R$204,007.13 in the next 6 week
# Store Number 912 will sell R$244,674.02 in the next 6 week
# Store Number 913 will sell R$175,606.97 in the next 6 week
# Store Number 914 will sell R$268,504.24 in the next 6 week
# Store Number 915 will sell R$204,175.39 in the next 6 week
# Store Number 916 will sell R$145,076.11 in the next 6 week
# Store Number 917 will sell R$160,565.99 in the next 6 week
# Store Number 919 will sell R$145,415.06 in the next 6 week
# Store Number 920 will sell R$146,649.31 in the next 6 week
# Store Number 922 will sell R$215,843.31 in the next 6 week
# Store Number 924 will sell R$135,732.20 in the next 6 week
# Store Number 925 will sell R$177,237.35 in the next 6 week
# Store Number 926 will sell R$260,308.33 in the next 6 week
# Store Number 927 will sell R$155,027.30 in the next 6 week
# Store Number 928 will sell R$244,984.78 in the next 6 week
# Store Number 929 will sell R$167,531.96 in the next 6 week
# Store Number 930 will sell R$148,695.58 in the next 6 week
# Store Number 931 will sell R$148,794.71 in the next 6 week
# Store Number 932 will sell R$151,823.05 in the next 6 week
# Store Number 934 will sell R$201,123.55 in the next 6 week
# Store Number 935 will sell R$184,639.02 in the next 6 week
# Store Number 936 will sell R$147,355.46 in the next 6 week
# Store Number 937 will sell R$150,910.06 in the next 6 week
# Store Number 938 will sell R$162,775.38 in the next 6 week
# Store Number 939 will sell R$211,279.71 in the next 6 week
# Store Number 941 will sell R$138,016.58 in the next 6 week
# Store Number 942 will sell R$244,054.83 in the next 6 week
# Store Number 943 will sell R$246,033.17 in the next 6 week
# Store Number 944 will sell R$203,408.87 in the next 6 week
# Store Number 945 will sell R$154,119.39 in the next 6 week
# Store Number 946 will sell R$110,338.80 in the next 6 week
# Store Number 947 will sell R$174,766.30 in the next 6 week
# Store Number 948 will sell R$251,412.14 in the next 6 week
# Store Number 950 will sell R$149,910.89 in the next 6 week
# Store Number 951 will sell R$256,569.28 in the next 6 week
# Store Number 952 will sell R$224,730.57 in the next 6 week
# Store Number 954 will sell R$128,526.64 in the next 6 week
# Store Number 955 will sell R$189,200.31 in the next 6 week
# Store Number 956 will sell R$127,949.85 in the next 6 week
# Store Number 960 will sell R$196,382.54 in the next 6 week
# Store Number 961 will sell R$233,723.53 in the next 6 week
# Store Number 962 will sell R$205,818.79 in the next 6 week
# Store Number 964 will sell R$182,384.00 in the next 6 week
# Store Number 965 will sell R$173,689.68 in the next 6 week
# Store Number 966 will sell R$127,578.56 in the next 6 week
# Store Number 967 will sell R$173,701.60 in the next 6 week
# Store Number 969 will sell R$141,723.56 in the next 6 week
# Store Number 970 will sell R$134,840.17 in the next 6 week
# Store Number 973 will sell R$202,189.60 in the next 6 week
# Store Number 974 will sell R$146,473.88 in the next 6 week
# Store Number 975 will sell R$195,984.53 in the next 6 week
# Store Number 976 will sell R$145,871.25 in the next 6 week
# Store Number 977 will sell R$127,424.54 in the next 6 week
# Store Number 980 will sell R$130,246.76 in the next 6 week
# Store Number 983 will sell R$142,801.00 in the next 6 week
# Store Number 984 will sell R$171,707.17 in the next 6 week
# Store Number 985 will sell R$267,382.86 in the next 6 week
# Store Number 986 will sell R$132,348.30 in the next 6 week
# Store Number 988 will sell R$147,390.54 in the next 6 week
# Store Number 989 will sell R$138,588.86 in the next 6 week
# Store Number 991 will sell R$154,020.17 in the next 6 week
# Store Number 992 will sell R$171,336.75 in the next 6 week
# Store Number 994 will sell R$128,688.81 in the next 6 week
# Store Number 997 will sell R$214,464.59 in the next 6 week
# Store Number 998 will sell R$110,159.77 in the next 6 week
# Store Number 1000 will sell R$181,621.57 in the next 6 week
# Store Number 1003 will sell R$139,146.54 in the next 6 week
# Store Number 1004 will sell R$207,653.77 in the next 6 week
# Store Number 1005 will sell R$150,794.40 in the next 6 week
# Store Number 1007 will sell R$230,362.73 in the next 6 week
# Store Number 1008 will sell R$176,330.22 in the next 6 week
# Store Number 1009 will sell R$103,071.39 in the next 6 week
# Store Number 1010 will sell R$269,987.53 in the next 6 week
# Store Number 1011 will sell R$216,495.77 in the next 6 week
# Store Number 1012 will sell R$251,149.93 in the next 6 week
# Store Number 1013 will sell R$136,703.94 in the next 6 week
# Store Number 1014 will sell R$178,046.53 in the next 6 week
# Store Number 1015 will sell R$215,294.54 in the next 6 week
# Store Number 1016 will sell R$229,818.07 in the next 6 week
# Store Number 1019 will sell R$271,757.38 in the next 6 week
# Store Number 1020 will sell R$166,521.55 in the next 6 week
# Store Number 1022 will sell R$189,579.18 in the next 6 week
# Store Number 1024 will sell R$244,934.60 in the next 6 week
# Store Number 1025 will sell R$163,678.58 in the next 6 week
# Store Number 1026 will sell R$222,060.76 in the next 6 week
# Store Number 1027 will sell R$239,513.52 in the next 6 week
# Store Number 1028 will sell R$129,033.69 in the next 6 week
# Store Number 1031 will sell R$221,402.46 in the next 6 week
# Store Number 1036 will sell R$185,914.51 in the next 6 week
# Store Number 1037 will sell R$178,126.25 in the next 6 week
# Store Number 1038 will sell R$204,399.13 in the next 6 week
# Store Number 1039 will sell R$254,782.21 in the next 6 week
# Store Number 1040 will sell R$166,085.24 in the next 6 week
# Store Number 1041 will sell R$189,769.99 in the next 6 week
# Store Number 1042 will sell R$144,569.95 in the next 6 week
# Store Number 1044 will sell R$214,465.89 in the next 6 week
# Store Number 1045 will sell R$262,796.99 in the next 6 week
# Store Number 1047 will sell R$164,588.78 in the next 6 week
# Store Number 1048 will sell R$271,331.50 in the next 6 week
# Store Number 1049 will sell R$153,640.13 in the next 6 week
# Store Number 1050 will sell R$261,564.38 in the next 6 week
# Store Number 1051 will sell R$243,884.38 in the next 6 week
# Store Number 1052 will sell R$205,883.29 in the next 6 week
# Store Number 1053 will sell R$193,950.54 in the next 6 week
# Store Number 1054 will sell R$197,321.53 in the next 6 week
# Store Number 1056 will sell R$190,929.08 in the next 6 week
# Store Number 1057 will sell R$254,011.99 in the next 6 week
# Store Number 1058 will sell R$227,243.92 in the next 6 week
# Store Number 1059 will sell R$257,264.29 in the next 6 week
# Store Number 1060 will sell R$200,066.71 in the next 6 week
# Store Number 1061 will sell R$277,623.29 in the next 6 week
# Store Number 1062 will sell R$186,074.60 in the next 6 week
# Store Number 1063 will sell R$153,456.71 in the next 6 week
# Store Number 1064 will sell R$236,000.34 in the next 6 week
# Store Number 1065 will sell R$139,863.47 in the next 6 week
# Store Number 1066 will sell R$219,096.70 in the next 6 week
# Store Number 1067 will sell R$250,339.43 in the next 6 week
# Store Number 1068 will sell R$180,002.70 in the next 6 week
# Store Number 1070 will sell R$245,951.86 in the next 6 week
# Store Number 1071 will sell R$170,010.09 in the next 6 week
# Store Number 1072 will sell R$198,191.82 in the next 6 week
# Store Number 1073 will sell R$205,666.10 in the next 6 week
# Store Number 1076 will sell R$159,582.95 in the next 6 week
# Store Number 1077 will sell R$159,097.99 in the next 6 week
# Store Number 1078 will sell R$275,763.59 in the next 6 week
# Store Number 1079 will sell R$194,480.52 in the next 6 week
# Store Number 1080 will sell R$199,222.08 in the next 6 week
# Store Number 1083 will sell R$202,581.44 in the next 6 week
# Store Number 1084 will sell R$160,758.78 in the next 6 week
# Store Number 1086 will sell R$165,108.88 in the next 6 week
# Store Number 1087 will sell R$254,830.66 in the next 6 week
# Store Number 1088 will sell R$150,661.82 in the next 6 week
# Store Number 1089 will sell R$310,129.80 in the next 6 week
# Store Number 1091 will sell R$247,753.52 in the next 6 week
# Store Number 1092 will sell R$289,518.74 in the next 6 week
# Store Number 1094 will sell R$144,937.22 in the next 6 week
# Store Number 1096 will sell R$147,308.25 in the next 6 week
# Store Number 1097 will sell R$405,842.33 in the next 6 week
# Store Number 1099 will sell R$221,399.31 in the next 6 week
# Store Number 1100 will sell R$157,153.33 in the next 6 week
# Store Number 1101 will sell R$326,635.20 in the next 6 week
# Store Number 1102 will sell R$169,856.48 in the next 6 week
# Store Number 1103 will sell R$199,609.14 in the next 6 week
# Store Number 1104 will sell R$178,021.11 in the next 6 week
# Store Number 1105 will sell R$189,347.86 in the next 6 week
# Store Number 1106 will sell R$167,715.18 in the next 6 week
# Store Number 1107 will sell R$179,288.76 in the next 6 week
# Store Number 1109 will sell R$171,798.61 in the next 6 week
# Store Number 1111 will sell R$140,869.85 in the next 6 week
# Store Number 1112 will sell R$312,529.52 in the next 6 week
# Store Number 1113 will sell R$191,864.50 in the next 6 week
# Store Number 1114 will sell R$450,490.77 in the next 6 week
# Store Number 1115 will sell R$248,801.18 in the next 6 week
# The sum of Predictions is 193,829,187.34
